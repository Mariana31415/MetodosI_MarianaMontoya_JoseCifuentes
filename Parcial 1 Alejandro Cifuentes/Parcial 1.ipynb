# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sym
from math import e

# %%
x=np.linspace(-2, 2, 50)

# %%
def f(x):
    return e**(-x)-x

# %%
X=[0,0.5000009536743164, 1]
Y=[1,0,0.6321205588285577]

# %%
f(0.5000009536743164)
# Out:
# 0.10652912760588062

# %%
def bolzano(a,b):
    xn=(a+b)/2
    xn1=b
    error=1
    
 
    while error>1e-6:
        xn1=(xn+xn1)/2
        error=abs(xn-xn1)
        
    return xn1

# %%
bolzano(0,1)
# Out:
# 0.5000009536743164

# %%
plt.plot(x,y)
plt.axhline(y = 0,color='r')

# %%
def funcion(x):
    return 1-x+1.63212056*x**(2)

# %%
def bhaskara(a,b,c):
    
    return (-2*c)/(b-np.sqrt( b**(2)-4*a*c))
