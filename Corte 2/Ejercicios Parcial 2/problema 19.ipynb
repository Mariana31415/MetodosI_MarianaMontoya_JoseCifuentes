# %%
#19
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import numpy as np
import sympy as sym
import math as m
from math import e
import matplotlib.pyplot as plt
sym.init_printing(use_unicode=True)
Td = 300
N0v = 300
x = sym.Symbol('x',real=True)
y = sym.Symbol('y',real=True)
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import matplotlib.pyplot as plt
import numpy as np

def funcion(T,dT):
    return 1/2*(sym.tanh(sym.sqrt(x**2 + dT**2)*(Td/2*T))/sym.sqrt(x**2+dT**2))


#Utilizando gauss legendre

# %%
#Polinomio legendre
n = 50
def GetLegendre(n,x,y):
    
    y = (x**2 - 1)**n
    
    poly = sym.diff( y,x,n )/(2**n*np.math.factorial(n))
    
    return poly

polinomio = GetLegendre(50,x,y)
print(polinomio)
# Out:
# (140737488355328*x**50 + 86201711617638400*x**48*(x**2 - 1) + 12154441338087014400*x**46*(x**2 - 1)**2 + 698880376940003328000*x**44*(x**2 - 1)**3 + 20660651143288848384000*x**42*(x**2 - 1)**4 + 355776412687433969172480*x**40*(x**2 - 1)**5 + 3854244470780534666035200*x**38*(x**2 - 1)**6 + 27648304724068529287987200*x**36*(x**2 - 1)**7 + 136081499813774792589312000*x**34*(x**2 - 1)**8 + 471245193799553448411136000*x**32*(x**2 - 1)**9 + 1168688080622892552059617280*x**30*(x**2 - 1)**10 + 2100740971367596116305510400*x**28*(x**2 - 1)**11 + 2757222524919969902650982400*x**26*(x**2 - 1)**12 + 2651175504730740291010560000*x**24*(x**2 - 1)**13 + 1866643977820623266119680000*x**22*(x**2 - 1)**14 + 958210575281253276608102400*x**20*(x**2 - 1)**15 + 355585955670777583116288000*x**18*(x**2 - 1)**16 + 94125694148147007295488000*x**16*(x**2 - 1)**17 + 17430684101508705054720000*x**14*(x**2 - 1)**18 + 2196942178999019612160000*x**12*(x**2 - 1)**19 + 181247729767419118003200*x**10*(x**2 - 1)**20 + 9247333151398934592000*x**8*(x**2 - 1)**21 + 267484843222283232000*x**6*(x**2 - 1)**22 + 3792318193132560000*x**4*(x**2 - 1)**23 + 19751657255898750*x**2*(x**2 - 1)**24 + 15801325804719*(x**2 - 1)**25)/140737488355328
# C:\Users\Flutt\AppData\Local\Temp\ipykernel_30384\883359404.py:7: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   poly = sym.diff( y,x,n )/(2**n*np.math.factorial(n))

# %%
#Obtener raices
def GetNewton(f,df,xn,itmax=10000,precision=1e-14):
    
    error = 1.
    it = 0
    
    while error >= precision and it < itmax:
        
        try:
            
            xn1 = xn - f(xn)/df(xn)
            
            error = np.abs(f(xn)/df(xn))
            
        except ZeroDivisionError:
            print('Zero Division')
            
        xn = xn1
        it += 1
        
    if it == itmax:
        return False
    else:
        return xn
    

def GetRoots(f,df,x,tolerancia = 10):
    
    Roots = np.array([])
    
    for i in x:
        
        root = GetNewton(f,df,i)

        if  type(root)!=bool:
            croot = np.round( root, tolerancia )
            
            if croot not in Roots:
                Roots = np.append(Roots, croot)
                
    Roots.sort()
    
    return Roots

# %%
Legendre = []
DLegendre = []

for i in range(n+1):
    Poly = GetLegendre(i,x,y)
    Legendre.append(Poly)
    DLegendre.append(sym.diff(Poly,x,1))
# Out:
# C:\Users\Flutt\AppData\Local\Temp\ipykernel_30384\883359404.py:7: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   poly = sym.diff( y,x,n )/(2**n*np.math.factorial(n))
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sympy\core\assumptions.py:499, in make_property.<locals>.getit(self)
#     498 try:
# --> 499     return self._assumptions[fact]
#     500 except KeyError:
#
# KeyError: 'zero'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Flutt\OneDrive\Documentos\Universidad\Metodos Computacionales I\Ejercicios libro 2\problema 19.ipynb Cell 5 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/Flutt/OneDrive/Documentos/Universidad/Metodos%20Computacionales%20I/Ejercicios%20libro%202/problema%2019.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> DLegendre = []
#       <a href='vscode-notebook-cell:/c%3A/Users/Flutt/OneDrive/Documentos/Universidad/Metodos%20Computacionales%20I/Ejercicios%20libro%202/problema%2019.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> for i in range(n+1):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Flutt/OneDrive/Documentos/Universidad/Metodos%20Computacionales%20I/Ejercicios%20libro%202/problema%2019.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a>     Poly = GetLegendre(i,x,y)
#       <a href='vscode-notebook-cell:/c%3A/Users/Flutt/OneDrive/Documentos/Universidad/Metodos%20Computacionales%20I/Ejercicios%20libro%202/problema%2019.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a>     Legendre.append(Poly)
#       <a href='vscode-notebook-cell:/c%3A/Users/Flutt/OneDrive/Documentos/Universidad/Metodos%20Computacionales%20I/Ejercicios%20libro%202/problema%2019.ipynb#W4sZmlsZQ%3D%3D?line=6'>7</a>     DLegendre.append(sym.diff(Poly,x,1))
#
# c:\Users\Flutt\OneDrive\Documentos\Universidad\Metodos Computacionales I\Ejercicios libro 2\problema 19.ipynb Cell 5 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/Flutt/OneDrive/Documentos/Universidad/Metodos%20Computacionales%20I/Ejercicios%20libro%202/problema%2019.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> def GetLegendre(n,x,y):
#       <a href='vscode-notebook-cell:/c%3A/Users/Flutt/OneDrive/Documentos/Universidad/Metodos%20Computacionales%20I/Ejercicios%20libro%202/problema%2019.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a>     y = (x**2 - 1)**n
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Flutt/OneDrive/Documentos/Universidad/Metodos%20Computacionales%20I/Ejercicios%20libro%202/problema%2019.ipynb#W4sZmlsZQ%3D%3D?line=6'>7</a>     poly = sym.diff( y,x,n )/(2**n*np.math.factorial(n))
#       <a href='vscode-notebook-cell:/c%3A/Users/Flutt/OneDrive/Documentos/Universidad/Metodos%20Computacionales%20I/Ejercicios%20libro%202/problema%2019.ipynb#W4sZmlsZQ%3D%3D?line=8'>9</a>     return poly
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sympy\core\function.py:2482, in diff(f, *symbols, **kwargs)
#    2418 """
#    2419 Differentiate f with respect to symbols.
#    2420
#    (...)
#    2479
#    2480 """
#    2481 if hasattr(f, 'diff'):
# -> 2482     return f.diff(*symbols, **kwargs)
#    2483 kwargs.setdefault('evaluate', True)
#    2484 return _derivative_dispatch(f, *symbols, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sympy\core\expr.py:3586, in Expr.diff(self, *symbols, **assumptions)
#    3584 def diff(self, *symbols, **assumptions):
#    3585     assumptions.setdefault("evaluate", True)
# -> 3586     return _derivative_dispatch(self, *symbols, **assumptions)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sympy\core\function.py:1909, in _derivative_dispatch(expr, *variables, **kwargs)
#    1907     from sympy.tensor.array.array_derivatives import ArrayDerivative
#    1908     return ArrayDerivative(expr, *variables, **kwargs)
# -> 1909 return Derivative(expr, *variables, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sympy\core\function.py:1437, in Derivative.__new__(cls, expr, *variables, **kwargs)
#    1430     if not old_v.is_scalar and not hasattr(
#    1431             old_v, '_eval_derivative'):
#    1432         # special hack providing evaluation for classes
#    1433         # that have defined is_scalar=True but have no
#    1434         # _eval_derivative defined
#    1435         expr *= old_v.diff(old_v)
# -> 1437 obj = cls._dispatch_eval_derivative_n_times(expr, v, count)
#    1438 if obj is not None and obj.is_zero:
#    1439     return obj
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sympy\core\function.py:1898, in Derivative._dispatch_eval_derivative_n_times(cls, expr, v, count)
#    1892 @classmethod
#    1893 def _dispatch_eval_derivative_n_times(cls, expr, v, count):
#    1894     # Evaluate the derivative `n` times.  If
#    1895     # `_eval_derivative_n_times` is not overridden by the current
#    1896     # object, the default in `Basic` will call a loop over
#    1897     # `_eval_derivative`:
# -> 1898     return expr._eval_derivative_n_times(v, count)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sympy\core\basic.py:1871, in Basic._eval_derivative_n_times(self, s, n)
#    1869 obj = self
#    1870 for i in range(n):
# -> 1871     obj2 = obj._eval_derivative(s)
#    1872     if obj == obj2 or obj2 is None:
#    1873         break
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sympy\core\cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sympy\core\add.py:507, in Add._eval_derivative(self, s)
#     505 @cacheit
#     506 def _eval_derivative(self, s):
# --> 507     return self.func(*[a.diff(s) for a in self.args])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sympy\core\cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sympy\core\operations.py:98, in AssocOp.__new__(cls, evaluate, _sympify, *args)
#      95 if len(args) == 1:
#      96     return args[0]
# ---> 98 c_part, nc_part, order_symbols = cls.flatten(args)
#      99 is_commutative = not nc_part
#     100 obj = cls._from_args(c_part + nc_part, is_commutative)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sympy\core\add.py:321, in Add.flatten(cls, seq)
#     318 noncommutative = False
#     319 for s, c in terms.items():
#     320     # 0*s
# --> 321     if c.is_zero:
#     322         continue
#     323     # 1*s
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sympy\core\assumptions.py:503, in make_property.<locals>.getit(self)
#     501 if self._assumptions is self.default_assumptions:
#     502     self._assumptions = self.default_assumptions.copy()
# --> 503 return _ask(fact, self)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sympy\core\assumptions.py:566, in _ask(fact, obj)
#     561 # If we get a new value for fact_i then we should update our knowledge
#     562 # of fact_i as well as any related facts that can be inferred using the
#     563 # inference rules connecting the fact_i and any other fact values that
#     564 # are already known.
#     565 if fact_i_value is not None:
# --> 566     assumptions.deduce_all_facts(((fact_i, fact_i_value),))
#     568 # Usually if assumptions[fact] is now not None then that is because of
#     569 # the call to deduce_all_facts above. The handler for fact_i returned
#     570 # True or False and knowing fact_i (which is equal to fact in the first
#    (...)
#     573 # called in another thread in a multithreaded context might have
#     574 # resulted in assumptions[fact] being set. Either way we return it.
#     575 fact_value = assumptions.get(fact)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sympy\core\facts.py:625, in FactKB.deduce_all_facts(self, facts)
#     623     # lookup routing tables
#     624     for key, value in full_implications[k, v]:
# --> 625         self._tell(key, value)
#     627     beta_maytrigger.update(beta_triggers[k, v])
#     629 # --- beta chains ---
#
# KeyboardInterrupt:

# %%
n = 50
def GetAllRoots(n,xn,Legendre,DLegendre):
    
    poly = sym.lambdify([x],Legendre[n],'numpy')
    Dpoly = sym.lambdify([x],DLegendre[n],'numpy')
    Roots = GetRoots(poly,Dpoly,xn)
    
    return Roots

# %%
Legendre
# Out:
# ⎡                                                                2    ⎛
# ⎢         2        ⎛   2    ⎞     4       2 ⎛ 2    ⎞     ⎛ 2    ⎞     ⎜   4
# ⎢      3⋅x  - 1  x⋅⎝5⋅x  - 3⎠  8⋅x  + 24⋅x ⋅⎝x  - 1⎠ + 3⋅⎝x  - 1⎠   x⋅⎝8⋅x  +
# ⎢1, x, ────────, ────────────, ───────────────────────────────────, ──────────
# ⎣         2           2                         8
#
#                             2⎞                                          2
#     2 ⎛ 2    ⎞      ⎛ 2    ⎞ ⎟      6        4 ⎛ 2    ⎞       2 ⎛ 2    ⎞
# 40⋅x ⋅⎝x  - 1⎠ + 15⋅⎝x  - 1⎠ ⎠  16⋅x  + 120⋅x ⋅⎝x  - 1⎠ + 90⋅x ⋅⎝x  - 1⎠  + 5⋅
# ──────────────────────────────, ──────────────────────────────────────────────
#          8                                                 16
#
#         3    ⎛                                         2              3⎞
# ⎛ 2    ⎞     ⎜    6        4 ⎛ 2    ⎞        2 ⎛ 2    ⎞       ⎛ 2    ⎞ ⎟
# ⎝x  - 1⎠   x⋅⎝16⋅x  + 168⋅x ⋅⎝x  - 1⎠ + 210⋅x ⋅⎝x  - 1⎠  + 35⋅⎝x  - 1⎠ ⎠  128⋅
# ─────────, ─────────────────────────────────────────────────────────────, ────
#                                          16
#
#                                         2                   3              4
#  8         6 ⎛ 2    ⎞         4 ⎛ 2    ⎞          2 ⎛ 2    ⎞       ⎛ 2    ⎞
# x  + 1792⋅x ⋅⎝x  - 1⎠ + 3360⋅x ⋅⎝x  - 1⎠  + 1120⋅x ⋅⎝x  - 1⎠  + 35⋅⎝x  - 1⎠
# ────────────────────────────────────────────────────────────────────────────,
#                                   128
#
#   ⎛                                            2                   3
#   ⎜     8         6 ⎛ 2    ⎞         4 ⎛ 2    ⎞          2 ⎛ 2    ⎞        ⎛ 2
# x⋅⎝128⋅x  + 2304⋅x ⋅⎝x  - 1⎠ + 6048⋅x ⋅⎝x  - 1⎠  + 3360⋅x ⋅⎝x  - 1⎠  + 315⋅⎝x
# ──────────────────────────────────────────────────────────────────────────────
#                                          128
#
#      4⎞                                                2                    3
#     ⎞ ⎟       10         8 ⎛ 2    ⎞          6 ⎛ 2    ⎞           4 ⎛ 2    ⎞
#  - 1⎠ ⎠  256⋅x   + 5760⋅x ⋅⎝x  - 1⎠ + 20160⋅x ⋅⎝x  - 1⎠  + 16800⋅x ⋅⎝x  - 1⎠
# ───────, ─────────────────────────────────────────────────────────────────────
#                                                            256
#
#                   4              5    ⎛
#         2 ⎛ 2    ⎞       ⎛ 2    ⎞     ⎜     10         8 ⎛ 2    ⎞          6 ⎛
# + 3150⋅x ⋅⎝x  - 1⎠  + 63⋅⎝x  - 1⎠   x⋅⎝256⋅x   + 7040⋅x ⋅⎝x  - 1⎠ + 31680⋅x ⋅⎝
# ──────────────────────────────────, ──────────────────────────────────────────
#
#
#        2                    3                    4               5⎞
#  2    ⎞           4 ⎛ 2    ⎞           2 ⎛ 2    ⎞        ⎛ 2    ⎞ ⎟        12
# x  - 1⎠  + 36960⋅x ⋅⎝x  - 1⎠  + 11550⋅x ⋅⎝x  - 1⎠  + 693⋅⎝x  - 1⎠ ⎠  1024⋅x
# ───────────────────────────────────────────────────────────────────, ─────────
#            256
#
#                                          2                     3
#          10 ⎛ 2    ⎞           8 ⎛ 2    ⎞            6 ⎛ 2    ⎞            4 ⎛
# + 33792⋅x  ⋅⎝x  - 1⎠ + 190080⋅x ⋅⎝x  - 1⎠  + 295680⋅x ⋅⎝x  - 1⎠  + 138600⋅x ⋅⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                                        1024
#
#        4                    5               6    ⎛
#  2    ⎞           2 ⎛ 2    ⎞        ⎛ 2    ⎞     ⎜      12          10 ⎛ 2
# x  - 1⎠  + 16632⋅x ⋅⎝x  - 1⎠  + 231⋅⎝x  - 1⎠   x⋅⎝1024⋅x   + 39936⋅x  ⋅⎝x  - 1
# ─────────────────────────────────────────────, ───────────────────────────────
#
#
#                       2                     3                     4
# ⎞           8 ⎛ 2    ⎞            6 ⎛ 2    ⎞            4 ⎛ 2    ⎞           2
# ⎠ + 274560⋅x ⋅⎝x  - 1⎠  + 549120⋅x ⋅⎝x  - 1⎠  + 360360⋅x ⋅⎝x  - 1⎠  + 72072⋅x
# ──────────────────────────────────────────────────────────────────────────────
#                                     1024
#
#          5                6⎞
#  ⎛ 2    ⎞         ⎛ 2    ⎞ ⎟        14          12 ⎛ 2    ⎞           10 ⎛ 2
# ⋅⎝x  - 1⎠  + 3003⋅⎝x  - 1⎠ ⎠  2048⋅x   + 93184⋅x  ⋅⎝x  - 1⎠ + 768768⋅x  ⋅⎝x  -
# ────────────────────────────, ────────────────────────────────────────────────
#
#
#    2                      3                      4                     5
#   ⎞             8 ⎛ 2    ⎞             6 ⎛ 2    ⎞            4 ⎛ 2    ⎞
#  1⎠  + 1921920⋅x ⋅⎝x  - 1⎠  + 1681680⋅x ⋅⎝x  - 1⎠  + 504504⋅x ⋅⎝x  - 1⎠  + 420
# ──────────────────────────────────────────────────────────────────────────────
#                              2048
#
#               6               7    ⎛
#     2 ⎛ 2    ⎞        ⎛ 2    ⎞     ⎜      14           12 ⎛ 2    ⎞
# 42⋅x ⋅⎝x  - 1⎠  + 429⋅⎝x  - 1⎠   x⋅⎝2048⋅x   + 107520⋅x  ⋅⎝x  - 1⎠ + 1048320⋅x
# ───────────────────────────────, ─────────────────────────────────────────────
#
#
#            2                      3                      4
# 10 ⎛ 2    ⎞             8 ⎛ 2    ⎞             6 ⎛ 2    ⎞             4 ⎛ 2
#   ⋅⎝x  - 1⎠  + 3203200⋅x ⋅⎝x  - 1⎠  + 3603600⋅x ⋅⎝x  - 1⎠  + 1513512⋅x ⋅⎝x  -
# ──────────────────────────────────────────────────────────────────────────────
#                                     2048
#
#   5                     6                7⎞
#  ⎞            2 ⎛ 2    ⎞         ⎛ 2    ⎞ ⎟         16            14 ⎛ 2    ⎞
# 1⎠  + 210210⋅x ⋅⎝x  - 1⎠  + 6435⋅⎝x  - 1⎠ ⎠  32768⋅x   + 1966080⋅x  ⋅⎝x  - 1⎠
# ───────────────────────────────────────────, ─────────────────────────────────
#
#
#                        2                        3                        4
#             12 ⎛ 2    ⎞              10 ⎛ 2    ⎞               8 ⎛ 2    ⎞
# + 22364160⋅x  ⋅⎝x  - 1⎠  + 82001920⋅x  ⋅⎝x  - 1⎠  + 115315200⋅x ⋅⎝x  - 1⎠  + 6
# ──────────────────────────────────────────────────────────────────────────────
#                                                              32768
#
#                    5                       6                     7
#          6 ⎛ 2    ⎞              4 ⎛ 2    ⎞            2 ⎛ 2    ⎞         ⎛ 2
# 4576512⋅x ⋅⎝x  - 1⎠  + 13453440⋅x ⋅⎝x  - 1⎠  + 823680⋅x ⋅⎝x  - 1⎠  + 6435⋅⎝x
# ──────────────────────────────────────────────────────────────────────────────
#
#
#     8    ⎛                                                        2
#    ⎞     ⎜       16            14 ⎛ 2    ⎞             12 ⎛ 2    ⎞
# - 1⎠   x⋅⎝32768⋅x   + 2228224⋅x  ⋅⎝x  - 1⎠ + 29245440⋅x  ⋅⎝x  - 1⎠  + 12673024
# ─────, ───────────────────────────────────────────────────────────────────────
#
#
#               3                        4                        5
#    10 ⎛ 2    ⎞               8 ⎛ 2    ⎞               6 ⎛ 2    ⎞
# 0⋅x  ⋅⎝x  - 1⎠  + 217817600⋅x ⋅⎝x  - 1⎠  + 156828672⋅x ⋅⎝x  - 1⎠  + 45741696⋅x
# ──────────────────────────────────────────────────────────────────────────────
#                             32768
#
#           6                      7                  8⎞
# 4 ⎛ 2    ⎞             2 ⎛ 2    ⎞           ⎛ 2    ⎞ ⎟         18            1
#  ⋅⎝x  - 1⎠  + 4667520⋅x ⋅⎝x  - 1⎠  + 109395⋅⎝x  - 1⎠ ⎠  65536⋅x   + 5013504⋅x
# ──────────────────────────────────────────────────────, ──────────────────────
#
#
#                                   2                         3
# 6 ⎛ 2    ⎞             14 ⎛ 2    ⎞               12 ⎛ 2    ⎞               10
#  ⋅⎝x  - 1⎠ + 75202560⋅x  ⋅⎝x  - 1⎠  + 380190720⋅x  ⋅⎝x  - 1⎠  + 784143360⋅x  ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#         4                        5                        6
# ⎛ 2    ⎞               8 ⎛ 2    ⎞               6 ⎛ 2    ⎞              4 ⎛ 2
# ⎝x  - 1⎠  + 705729024⋅x ⋅⎝x  - 1⎠  + 274450176⋅x ⋅⎝x  - 1⎠  + 42007680⋅x ⋅⎝x
# ──────────────────────────────────────────────────────────────────────────────
#          65536
#
#     7                      8                 9    ⎛
#    ⎞             2 ⎛ 2    ⎞          ⎛ 2    ⎞     ⎜       18            16 ⎛ 2
# - 1⎠  + 1969110⋅x ⋅⎝x  - 1⎠  + 12155⋅⎝x  - 1⎠   x⋅⎝65536⋅x   + 5603328⋅x  ⋅⎝x
# ──────────────────────────────────────────────, ──────────────────────────────
#
#
#                              2                         3
#     ⎞             14 ⎛ 2    ⎞               12 ⎛ 2    ⎞                10 ⎛ 2
#  - 1⎠ + 95256576⋅x  ⋅⎝x  - 1⎠  + 555663360⋅x  ⋅⎝x  - 1⎠  + 1354429440⋅x  ⋅⎝x
# ──────────────────────────────────────────────────────────────────────────────
#
#
#     4                         5                        6
#    ⎞                8 ⎛ 2    ⎞               6 ⎛ 2    ⎞               4 ⎛ 2
# - 1⎠  + 1489872384⋅x ⋅⎝x  - 1⎠  + 744936192⋅x ⋅⎝x  - 1⎠  + 159629184⋅x ⋅⎝x  -
# ──────────────────────────────────────────────────────────────────────────────
#       65536
#
#   7                       8                  9⎞
#  ⎞              2 ⎛ 2    ⎞           ⎛ 2    ⎞ ⎟          20             18 ⎛ 2
# 1⎠  + 12471030⋅x ⋅⎝x  - 1⎠  + 230945⋅⎝x  - 1⎠ ⎠  262144⋅x   + 24903680⋅x  ⋅⎝x
# ───────────────────────────────────────────────, ─────────────────────────────
#
#
#                               2                          3
#     ⎞              16 ⎛ 2    ⎞                14 ⎛ 2    ⎞                12 ⎛
#  - 1⎠ + 476282880⋅x  ⋅⎝x  - 1⎠  + 3175219200⋅x  ⋅⎝x  - 1⎠  + 9029529600⋅x  ⋅⎝x
# ──────────────────────────────────────────────────────────────────────────────
#
#
#       4                           5                         6
# 2    ⎞                 10 ⎛ 2    ⎞                8 ⎛ 2    ⎞                6
#   - 1⎠  + 11918979072⋅x  ⋅⎝x  - 1⎠  + 7449361920⋅x ⋅⎝x  - 1⎠  + 2128389120⋅x ⋅
# ──────────────────────────────────────────────────────────────────────────────
#                      262144
#
#         7                        8                      9                 10
# ⎛ 2    ⎞               4 ⎛ 2    ⎞             2 ⎛ 2    ⎞          ⎛ 2    ⎞
# ⎝x  - 1⎠  + 249420600⋅x ⋅⎝x  - 1⎠  + 9237800⋅x ⋅⎝x  - 1⎠  + 46189⋅⎝x  - 1⎠
# ────────────────────────────────────────────────────────────────────────────,
#
#
#   ⎛                                                           2
#   ⎜        20             18 ⎛ 2    ⎞              16 ⎛ 2    ⎞
# x⋅⎝262144⋅x   + 27525120⋅x  ⋅⎝x  - 1⎠ + 588349440⋅x  ⋅⎝x  - 1⎠  + 4445306880⋅x
# ──────────────────────────────────────────────────────────────────────────────
#
#
#            3                           4                           5
# 14 ⎛ 2    ⎞                 12 ⎛ 2    ⎞                 10 ⎛ 2    ⎞
#   ⋅⎝x  - 1⎠  + 14586163200⋅x  ⋅⎝x  - 1⎠  + 22754414592⋅x  ⋅⎝x  - 1⎠  + 1738184
# ──────────────────────────────────────────────────────────────────────────────
#                                                       262144
#
#                 6                         7                         8
#       8 ⎛ 2    ⎞                6 ⎛ 2    ⎞                4 ⎛ 2    ⎞
# 4480⋅x ⋅⎝x  - 1⎠  + 6385167360⋅x ⋅⎝x  - 1⎠  + 1047566520⋅x ⋅⎝x  - 1⎠  + 646646
# ──────────────────────────────────────────────────────────────────────────────
#
#
#               9                  10⎞
#     2 ⎛ 2    ⎞           ⎛ 2    ⎞  ⎟          22             20 ⎛ 2    ⎞
# 00⋅x ⋅⎝x  - 1⎠  + 969969⋅⎝x  - 1⎠  ⎠  524288⋅x   + 60555264⋅x  ⋅⎝x  - 1⎠ + 143
# ────────────────────────────────────, ────────────────────────────────────────
#
#
#                     2                           3                           4
#          18 ⎛ 2    ⎞                 16 ⎛ 2    ⎞                 14 ⎛ 2    ⎞
# 8187520⋅x  ⋅⎝x  - 1⎠  + 12224593920⋅x  ⋅⎝x  - 1⎠  + 45842227200⋅x  ⋅⎝x  - 1⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                           5                           6
#                12 ⎛ 2    ⎞                 10 ⎛ 2    ⎞                 8 ⎛ 2
# + 83432853504⋅x  ⋅⎝x  - 1⎠  + 76480115712⋅x  ⋅⎝x  - 1⎠  + 35118420480⋅x ⋅⎝x  -
# ──────────────────────────────────────────────────────────────────────────────
#                            524288
#
#    7                         8                        9
#   ⎞                6 ⎛ 2    ⎞               4 ⎛ 2    ⎞              2 ⎛ 2    ⎞
#  1⎠  + 7682154480⋅x ⋅⎝x  - 1⎠  + 711310600⋅x ⋅⎝x  - 1⎠  + 21339318⋅x ⋅⎝x  - 1⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
# 10                 11    ⎛
#            ⎛ 2    ⎞      ⎜        22             20 ⎛ 2    ⎞               18
#    + 88179⋅⎝x  - 1⎠    x⋅⎝524288⋅x   + 66322432⋅x  ⋅⎝x  - 1⎠ + 1740963840⋅x  ⋅
# ─────────────────────, ───────────────────────────────────────────────────────
#
#
#         2                           3                           4
# ⎛ 2    ⎞                 16 ⎛ 2    ⎞                 14 ⎛ 2    ⎞
# ⎝x  - 1⎠  + 16539156480⋅x  ⋅⎝x  - 1⎠  + 70291415040⋅x  ⋅⎝x  - 1⎠  + 1476119715
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                5                            6                          7
#     12 ⎛ 2    ⎞                  10 ⎛ 2    ⎞                 8 ⎛ 2    ⎞
# 84⋅x  ⋅⎝x  - 1⎠  + 159912969216⋅x  ⋅⎝x  - 1⎠  + 89747074560⋅x ⋅⎝x  - 1⎠  + 252
# ──────────────────────────────────────────────────────────────────────────────
#                  524288
#
#                     8                         9                        10
#           6 ⎛ 2    ⎞                4 ⎛ 2    ⎞               2 ⎛ 2    ⎞
# 41364720⋅x ⋅⎝x  - 1⎠  + 3272028760⋅x ⋅⎝x  - 1⎠  + 163601438⋅x ⋅⎝x  - 1⎠   + 20
# ──────────────────────────────────────────────────────────────────────────────
#
#
#               11⎞
#       ⎛ 2    ⎞  ⎟           24              22 ⎛ 2    ⎞                20 ⎛ 2
# 28117⋅⎝x  - 1⎠  ⎠  4194304⋅x   + 578813952⋅x  ⋅⎝x  - 1⎠ + 16713252864⋅x  ⋅⎝x
# ─────────────────, ───────────────────────────────────────────────────────────
#
#
#     2                            3                            4
#    ⎞                  18 ⎛ 2    ⎞                  16 ⎛ 2    ⎞
# - 1⎠  + 176417669120⋅x  ⋅⎝x  - 1⎠  + 843496980480⋅x  ⋅⎝x  - 1⎠  + 202439275315
# ──────────────────────────────────────────────────────────────────────────────
#
#
#               5                             6                             7
#    14 ⎛ 2    ⎞                   12 ⎛ 2    ⎞                   10 ⎛ 2    ⎞
# 2⋅x  ⋅⎝x  - 1⎠  + 2558607507456⋅x  ⋅⎝x  - 1⎠  + 1723143831552⋅x  ⋅⎝x  - 1⎠  +
# ──────────────────────────────────────────────────────────────────────────────
#                               4194304
#
#                         8                           9
#               8 ⎛ 2    ⎞                  6 ⎛ 2    ⎞                4 ⎛ 2    ⎞
# 605792753280⋅x ⋅⎝x  - 1⎠  + 104704920320⋅x ⋅⎝x  - 1⎠  + 7852869024⋅x ⋅⎝x  - 1⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
# 10                        11                  12    ⎛
#                 2 ⎛ 2    ⎞            ⎛ 2    ⎞      ⎜         24
#    + 194699232⋅x ⋅⎝x  - 1⎠   + 676039⋅⎝x  - 1⎠    x⋅⎝4194304⋅x   + 629145600⋅x
# ────────────────────────────────────────────────, ────────────────────────────
#
#
#                                       2                            3
# 22 ⎛ 2    ⎞                20 ⎛ 2    ⎞                  18 ⎛ 2    ⎞
#   ⋅⎝x  - 1⎠ + 19896729600⋅x  ⋅⎝x  - 1⎠  + 232128512000⋅x  ⋅⎝x  - 1⎠  + 1240436
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                    4                             5
#         16 ⎛ 2    ⎞                   14 ⎛ 2    ⎞                   12 ⎛ 2
# 736000⋅x  ⋅⎝x  - 1⎠  + 3373987921920⋅x  ⋅⎝x  - 1⎠  + 4920399052800⋅x  ⋅⎝x  - 1
# ──────────────────────────────────────────────────────────────────────────────
#                                                                   4194304
#
#  6                             7                            8
# ⎞                   10 ⎛ 2    ⎞                   8 ⎛ 2    ⎞
# ⎠  + 3916235980800⋅x  ⋅⎝x  - 1⎠  + 1682757648000⋅x ⋅⎝x  - 1⎠  + 373946144000⋅x
# ──────────────────────────────────────────────────────────────────────────────
#
#
#           9                          10                         11
# 6 ⎛ 2    ⎞                 4 ⎛ 2    ⎞                 2 ⎛ 2    ⎞
#  ⋅⎝x  - 1⎠  + 39264345120⋅x ⋅⎝x  - 1⎠   + 1622493600⋅x ⋅⎝x  - 1⎠   + 16900975⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#         12⎞                                                                  2
# ⎛ 2    ⎞  ⎟           26               24 ⎛ 2    ⎞                22 ⎛ 2    ⎞
# ⎝x  - 1⎠  ⎠  8388608⋅x   + 1363148800⋅x  ⋅⎝x  - 1⎠ + 47028633600⋅x  ⋅⎝x  - 1⎠
# ───────────, ─────────────────────────────────────────────────────────────────
#
#
#                             3                             4
#                  20 ⎛ 2    ⎞                   18 ⎛ 2    ⎞
#  + 603534131200⋅x  ⋅⎝x  - 1⎠  + 3583483904000⋅x  ⋅⎝x  - 1⎠  + 10965460746240⋅x
# ──────────────────────────────────────────────────────────────────────────────
#
#
#            5                              6                              7
# 16 ⎛ 2    ⎞                    14 ⎛ 2    ⎞                    12 ⎛ 2    ⎞
#   ⋅⎝x  - 1⎠  + 18275767910400⋅x  ⋅⎝x  - 1⎠  + 16970355916800⋅x  ⋅⎝x  - 1⎠  + 8
# ──────────────────────────────────────────────────────────────────────────────
#                                            8388608
#
#                          8                            9
#               10 ⎛ 2    ⎞                   8 ⎛ 2    ⎞                  6 ⎛ 2
# 750339769600⋅x  ⋅⎝x  - 1⎠  + 2430649936000⋅x ⋅⎝x  - 1⎠  + 340290991040⋅x ⋅⎝x
# ──────────────────────────────────────────────────────────────────────────────
#
#
#     10                          11                        12
#    ⎞                  4 ⎛ 2    ⎞                2 ⎛ 2    ⎞             ⎛ 2
# - 1⎠   + 21092416800⋅x ⋅⎝x  - 1⎠   + 439425350⋅x ⋅⎝x  - 1⎠   + 1300075⋅⎝x  - 1
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  13    ⎛                                                                2
# ⎞      ⎜         26               24 ⎛ 2    ⎞                22 ⎛ 2    ⎞
# ⎠    x⋅⎝8388608⋅x   + 1472200704⋅x  ⋅⎝x  - 1⎠ + 55207526400⋅x  ⋅⎝x  - 1⎠  + 77
# ───, ─────────────────────────────────────────────────────────────────────────
#
#
#                        3                             4
#             20 ⎛ 2    ⎞                   18 ⎛ 2    ⎞                    16 ⎛
# 5972454400⋅x  ⋅⎝x  - 1⎠  + 5092319232000⋅x  ⋅⎝x  - 1⎠  + 17415731773440⋅x  ⋅⎝x
# ──────────────────────────────────────────────────────────────────────────────
#
#
#       5                              6                              7
# 2    ⎞                    14 ⎛ 2    ⎞                    12 ⎛ 2    ⎞
#   - 1⎠  + 32896382238720⋅x  ⋅⎝x  - 1⎠  + 35246123827200⋅x  ⋅⎝x  - 1⎠  + 214781
# ──────────────────────────────────────────────────────────────────────────────
#                                         8388608
#
#                      8                            9
#           10 ⎛ 2    ⎞                   8 ⎛ 2    ⎞                   6 ⎛ 2
# 06707200⋅x  ⋅⎝x  - 1⎠  + 7291949808000⋅x ⋅⎝x  - 1⎠  + 1312550965440⋅x ⋅⎝x  - 1
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  10                           11                         12
# ⎞                   4 ⎛ 2    ⎞                 2 ⎛ 2    ⎞              ⎛ 2
# ⎠   + 113899050720⋅x ⋅⎝x  - 1⎠   + 3954828150⋅x ⋅⎝x  - 1⎠   + 35102025⋅⎝x  - 1
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  13⎞                                                                    2
# ⎞  ⎟            28               26 ⎛ 2    ⎞                 24 ⎛ 2    ⎞
# ⎠  ⎠  33554432⋅x   + 6341787648⋅x  ⋅⎝x  - 1⎠ + 257635123200⋅x  ⋅⎝x  - 1⎠  + 39
# ────, ────────────────────────────────────────────────────────────────────────
#
#
#                         3                              4
#              22 ⎛ 2    ⎞                    20 ⎛ 2    ⎞                     18
# 50405222400⋅x  ⋅⎝x  - 1⎠  + 28516987699200⋅x  ⋅⎝x  - 1⎠  + 108364553256960⋅x
# ──────────────────────────────────────────────────────────────────────────────
#
#
#          5                               6                               7
#  ⎛ 2    ⎞                     16 ⎛ 2    ⎞                     14 ⎛ 2    ⎞
# ⋅⎝x  - 1⎠  + 230274675671040⋅x  ⋅⎝x  - 1⎠  + 281968990617600⋅x  ⋅⎝x  - 1⎠  + 2
# ──────────────────────────────────────────────────────────────────────────────
#                                                            33554432
#
#                            8                              9
#                 12 ⎛ 2    ⎞                    10 ⎛ 2    ⎞
# 00462329267200⋅x  ⋅⎝x  - 1⎠  + 81669837849600⋅x  ⋅⎝x  - 1⎠  + 18375713516160⋅x
# ──────────────────────────────────────────────────────────────────────────────
#
#
#           10                            11                           12
# 8 ⎛ 2    ⎞                    6 ⎛ 2    ⎞                   4 ⎛ 2    ⎞
#  ⋅⎝x  - 1⎠   + 2126115613440⋅x ⋅⎝x  - 1⎠   + 110735188200⋅x ⋅⎝x  - 1⎠   + 1965
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                   13                   14    ⎛
#         2 ⎛ 2    ⎞             ⎛ 2    ⎞      ⎜          28               26 ⎛
# 713400⋅x ⋅⎝x  - 1⎠   + 5014575⋅⎝x  - 1⎠    x⋅⎝33554432⋅x   + 6811549696⋅x  ⋅⎝x
# ─────────────────────────────────────────, ───────────────────────────────────
#
#
#                                   2                             3
# 2    ⎞                 24 ⎛ 2    ⎞                   22 ⎛ 2    ⎞
#   - 1⎠ + 298856742912⋅x  ⋅⎝x  - 1⎠  + 4980945715200⋅x  ⋅⎝x  - 1⎠  + 3938060206
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                  4                               5
#       20 ⎛ 2    ⎞                     18 ⎛ 2    ⎞                     16 ⎛ 2
# 0800⋅x  ⋅⎝x  - 1⎠  + 165398528655360⋅x  ⋅⎝x  - 1⎠  + 392821505556480⋅x  ⋅⎝x  -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#    6                               7                               8
#   ⎞                     14 ⎛ 2    ⎞                     12 ⎛ 2    ⎞
#  1⎠  + 545140048527360⋅x  ⋅⎝x  - 1⎠  + 447185196057600⋅x  ⋅⎝x  - 1⎠  + 2153113
# ──────────────────────────────────────────────────────────────────────────────
#                       33554432
#
#                      9                             10
#           10 ⎛ 2    ⎞                    8 ⎛ 2    ⎞                    6 ⎛ 2
# 90694400⋅x  ⋅⎝x  - 1⎠  + 59210632440960⋅x ⋅⎝x  - 1⎠   + 8808193255680⋅x ⋅⎝x  -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#    11                           12                          13
#   ⎞                   4 ⎛ 2    ⎞                  2 ⎛ 2    ⎞               ⎛ 2
#  1⎠   + 642264091560⋅x ⋅⎝x  - 1⎠   + 19001896200⋅x ⋅⎝x  - 1⎠   + 145422675⋅⎝x
# ──────────────────────────────────────────────────────────────────────────────
#
#
#      14⎞                                                                     2
#     ⎞  ⎟            30                28 ⎛ 2    ⎞                 26 ⎛ 2    ⎞
#  - 1⎠  ⎠  67108864⋅x   + 14596177920⋅x  ⋅⎝x  - 1⎠ + 689669406720⋅x  ⋅⎝x  - 1⎠
# ────────, ────────────────────────────────────────────────────────────────────
#
#
#                               3                               4
#                    24 ⎛ 2    ⎞                     22 ⎛ 2    ⎞
#  + 12452364288000⋅x  ⋅⎝x  - 1⎠  + 107401641984000⋅x  ⋅⎝x  - 1⎠  + 496195585966
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                 5                                6
#      20 ⎛ 2    ⎞                      18 ⎛ 2    ⎞                      16 ⎛ 2
# 080⋅x  ⋅⎝x  - 1⎠  + 1309405018521600⋅x  ⋅⎝x  - 1⎠  + 2044275181977600⋅x  ⋅⎝x
# ──────────────────────────────────────────────────────────────────────────────
#
#
#     7                                8                                9
#    ⎞                      14 ⎛ 2    ⎞                      12 ⎛ 2    ⎞
# - 1⎠  + 1916507983104000⋅x  ⋅⎝x  - 1⎠  + 1076556953472000⋅x  ⋅⎝x  - 1⎠  + 3552
# ──────────────────────────────────────────────────────────────────────────────
#      67108864
#
#                         10                             11
#              10 ⎛ 2    ⎞                     8 ⎛ 2    ⎞                    6 ⎛
# 63794645760⋅x  ⋅⎝x  - 1⎠   + 66061449417600⋅x ⋅⎝x  - 1⎠   + 6422640915600⋅x ⋅⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#        12                           13                         14
#  2    ⎞                   4 ⎛ 2    ⎞                 2 ⎛ 2    ⎞             ⎛
# x  - 1⎠   + 285028443000⋅x ⋅⎝x  - 1⎠   + 4362680250⋅x ⋅⎝x  - 1⎠   + 9694845⋅⎝x
# ──────────────────────────────────────────────────────────────────────────────
#
#
#       15    ⎛
# 2    ⎞      ⎜          30                28 ⎛ 2    ⎞                 26 ⎛ 2
#   - 1⎠    x⋅⎝67108864⋅x   + 15602810880⋅x  ⋅⎝x  - 1⎠ + 791842652160⋅x  ⋅⎝x  -
# ────────, ────────────────────────────────────────────────────────────────────
#
#
#   2                              3                               4
#  ⎞                    24 ⎛ 2    ⎞                     22 ⎛ 2    ⎞
# 1⎠  + 15440931717120⋅x  ⋅⎝x  - 1⎠  + 144758734848000⋅x  ⋅⎝x  - 1⎠  + 732479198
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                    5                                6
#         20 ⎛ 2    ⎞                      18 ⎛ 2    ⎞                      16 ⎛
# 330880⋅x  ⋅⎝x  - 1⎠  + 2136397661798400⋅x  ⋅⎝x  - 1⎠  + 3727795920076800⋅x  ⋅⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#        7                                8                                9
#  2    ⎞                      14 ⎛ 2    ⎞                      12 ⎛ 2    ⎞
# x  - 1⎠  + 3960783165081600⋅x  ⋅⎝x  - 1⎠  + 2567174273664000⋅x  ⋅⎝x  - 1⎠  + 1
# ──────────────────────────────────────────────────────────────────────────────
#            67108864
#
#                             10                              11
#                  10 ⎛ 2    ⎞                      8 ⎛ 2    ⎞
# 001197966728960⋅x  ⋅⎝x  - 1⎠   + 227544992438400⋅x ⋅⎝x  - 1⎠   + 2844312405480
# ──────────────────────────────────────────────────────────────────────────────
#
#
#              12                            13                          14
#    6 ⎛ 2    ⎞                    4 ⎛ 2    ⎞                  2 ⎛ 2    ⎞
# 0⋅x ⋅⎝x  - 1⎠   + 1767176346600⋅x ⋅⎝x  - 1⎠   + 45081029250⋅x ⋅⎝x  - 1⎠   + 30
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                 15⎞
#         ⎛ 2    ⎞  ⎟              32                 30 ⎛ 2    ⎞
# 0540195⋅⎝x  - 1⎠  ⎠  2147483648⋅x   + 532575944704⋅x  ⋅⎝x  - 1⎠ + 289588169932
# ───────────────────, ─────────────────────────────────────────────────────────
#
#
#                2                               3
#     28 ⎛ 2    ⎞                     26 ⎛ 2    ⎞                      24 ⎛ 2
# 80⋅x  ⋅⎝x  - 1⎠  + 608135156858880⋅x  ⋅⎝x  - 1⎠  + 6176372686848000⋅x  ⋅⎝x  -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#   4                                 5                                  6
#  ⎞                       22 ⎛ 2    ⎞                        20 ⎛ 2    ⎞
# 1⎠  + 34093577231400960⋅x  ⋅⎝x  - 1⎠  + 109383560284078080⋅x  ⋅⎝x  - 1⎠  + 212
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                             7                                  8
#                  18 ⎛ 2    ⎞                        16 ⎛ 2    ⎞
# 070167897702400⋅x  ⋅⎝x  - 1⎠  + 253490122565222400⋅x  ⋅⎝x  - 1⎠  + 18777046115
# ──────────────────────────────────────────────────────────────────────────────
#                                                2147483648
#
#                     9                                 10
#          14 ⎛ 2    ⎞                       12 ⎛ 2    ⎞
# 9424000⋅x  ⋅⎝x  - 1⎠  + 85435559827537920⋅x  ⋅⎝x  - 1⎠   + 23300607225692160⋅x
# ──────────────────────────────────────────────────────────────────────────────
#
#
#            11                               12                              13
# 10 ⎛ 2    ⎞                       8 ⎛ 2    ⎞                      6 ⎛ 2    ⎞
#   ⋅⎝x  - 1⎠   + 3640719879014400⋅x ⋅⎝x  - 1⎠   + 301598096486400⋅x ⋅⎝x  - 1⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                              14                           15
#                    4 ⎛ 2    ⎞                   2 ⎛ 2    ⎞               ⎛ 2
#  + 11540743488000⋅x ⋅⎝x  - 1⎠   + 153876579840⋅x ⋅⎝x  - 1⎠   + 300540195⋅⎝x  -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#    16    ⎛
#   ⎞      ⎜            32                 30 ⎛ 2    ⎞                   28 ⎛ 2
#  1⎠    x⋅⎝2147483648⋅x   + 566935683072⋅x  ⋅⎝x  - 1⎠ + 32953136578560⋅x  ⋅⎝x
# ─────, ───────────────────────────────────────────────────────────────────────
#
#
#     2                               3                                4
#    ⎞                     26 ⎛ 2    ⎞                      24 ⎛ 2    ⎞
# - 1⎠  + 743276302827520⋅x  ⋅⎝x  - 1⎠  + 8152811946639360⋅x  ⋅⎝x  - 1⎠  + 48916
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                          5                                  6
#               22 ⎛ 2    ⎞                        20 ⎛ 2    ⎞
# 871679836160⋅x  ⋅⎝x  - 1⎠  + 171888451874979840⋅x  ⋅⎝x  - 1⎠  + 36833239687495
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                  7                                  8
#       18 ⎛ 2    ⎞                        16 ⎛ 2    ⎞                        14
# 6800⋅x  ⋅⎝x  - 1⎠  + 492069061450137600⋅x  ⋅⎝x  - 1⎠  + 413095014550732800⋅x
# ──────────────────────────────────────────────────────────────────────────────
#                                       2147483648
#
#          9                                  10
#  ⎛ 2    ⎞                        12 ⎛ 2    ⎞                        10 ⎛ 2
# ⋅⎝x  - 1⎠  + 216874882639134720⋅x  ⋅⎝x  - 1⎠   + 69901821677076480⋅x  ⋅⎝x  - 1
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  11                                12                               13
# ⎞                        8 ⎛ 2    ⎞                       6 ⎛ 2    ⎞
# ⎠   + 13349306223052800⋅x ⋅⎝x  - 1⎠   + 1421819597721600⋅x ⋅⎝x  - 1⎠   + 76168
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                      14                            15                      16⎞
#            4 ⎛ 2    ⎞                    2 ⎛ 2    ⎞                ⎛ 2    ⎞  ⎟
# 907020800⋅x ⋅⎝x  - 1⎠   + 1692642378240⋅x ⋅⎝x  - 1⎠   + 9917826435⋅⎝x  - 1⎠  ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                                                                            2
#               34                  32 ⎛ 2    ⎞                   30 ⎛ 2    ⎞
#   4294967296⋅x   + 1204738326528⋅x  ⋅⎝x  - 1⎠ + 74693776244736⋅x  ⋅⎝x  - 1⎠  +
# , ────────────────────────────────────────────────────────────────────────────
#
#
#                               3                                 4
#                    28 ⎛ 2    ⎞                       26 ⎛ 2    ⎞
#  1805099592581120⋅x  ⋅⎝x  - 1⎠  + 21322738937364480⋅x  ⋅⎝x  - 1⎠  + 1385978030
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                      5                                  6
#           24 ⎛ 2    ⎞                        22 ⎛ 2    ⎞
# 92869120⋅x  ⋅⎝x  - 1⎠  + 531291578522664960⋅x  ⋅⎝x  - 1⎠  + 125233014937485312
# ──────────────────────────────────────────────────────────────────────────────
#
#
#               7                                   8
#    20 ⎛ 2    ⎞                         18 ⎛ 2    ⎞                         16
# 0⋅x  ⋅⎝x  - 1⎠  + 1858927565478297600⋅x  ⋅⎝x  - 1⎠  + 1755653811840614400⋅x  ⋅
# ──────────────────────────────────────────────────────────────────────────────
#                                                    4294967296
#
#         9                                   10
# ⎛ 2    ⎞                         14 ⎛ 2    ⎞                         12 ⎛ 2
# ⎝x  - 1⎠  + 1053392287104368640⋅x  ⋅⎝x  - 1⎠   + 396110322836766720⋅x  ⋅⎝x  -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#   11                                 12                                13
#  ⎞                        10 ⎛ 2    ⎞                        8 ⎛ 2    ⎞
# 1⎠   + 90775282316759040⋅x  ⋅⎝x  - 1⎠   + 12085466580633600⋅x ⋅⎝x  - 1⎠   + 86
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                          14                             15
#                6 ⎛ 2    ⎞                     4 ⎛ 2    ⎞                   2 ⎛
# 3247612902400⋅x ⋅⎝x  - 1⎠   + 28774920430080⋅x ⋅⎝x  - 1⎠   + 337206098790⋅x ⋅⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#        16                     17    ⎛
#  2    ⎞               ⎛ 2    ⎞      ⎜            34                  32 ⎛ 2
# x  - 1⎠   + 583401555⋅⎝x  - 1⎠    x⋅⎝4294967296⋅x   + 1277752770560⋅x  ⋅⎝x  -
# ────────────────────────────────, ────────────────────────────────────────────
#
#
#                                 2                                3
#  ⎞                   30 ⎛ 2    ⎞                      28 ⎛ 2    ⎞
# 1⎠ + 84331682856960⋅x  ⋅⎝x  - 1⎠  + 2178568473804800⋅x  ⋅⎝x  - 1⎠  + 276405875
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                      4                                  5
#           26 ⎛ 2    ⎞                        24 ⎛ 2    ⎞
# 11398400⋅x  ⋅⎝x  - 1⎠  + 194036924330016768⋅x  ⋅⎝x  - 1⎠  + 808487184708403200
# ──────────────────────────────────────────────────────────────────────────────
#
#
#              6                                   7
#   22 ⎛ 2    ⎞                         20 ⎛ 2    ⎞                         18 ⎛
# ⋅x  ⋅⎝x  - 1⎠  + 2087216915624755200⋅x  ⋅⎝x  - 1⎠  + 3424340252196864000⋅x  ⋅⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#        8                                   9
#  2    ⎞                         16 ⎛ 2    ⎞                         14 ⎛ 2
# x  - 1⎠  + 3614581377318912000⋅x  ⋅⎝x  - 1⎠  + 2457915336576860160⋅x  ⋅⎝x  - 1
# ──────────────────────────────────────────────────────────────────────────────
#            4294967296
#
#  10                                   11                                  12
# ⎞                          12 ⎛ 2    ⎞                         10 ⎛ 2    ⎞
# ⎠   + 1066450869175910400⋅x  ⋅⎝x  - 1⎠   + 288830443735142400⋅x  ⋅⎝x  - 1⎠   +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                               13                               14
#                     8 ⎛ 2    ⎞                       6 ⎛ 2    ⎞
#  46999036702464000⋅x ⋅⎝x  - 1⎠   + 4316238064512000⋅x ⋅⎝x  - 1⎠   + 2014244430
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                  15                            16                       17⎞
#        4 ⎛ 2    ⎞                    2 ⎛ 2    ⎞                 ⎛ 2    ⎞  ⎟
# 10560⋅x ⋅⎝x  - 1⎠   + 3934071152550⋅x ⋅⎝x  - 1⎠   + 20419054425⋅⎝x  - 1⎠  ⎠  1
# ───────────────────────────────────────────────────────────────────────────, ─
#
#
#                                                                           2
#             36                  34 ⎛ 2    ⎞                    32 ⎛ 2    ⎞
# 7179869184⋅x   + 5411658792960⋅x  ⋅⎝x  - 1⎠ + 379492572856320⋅x  ⋅⎝x  - 1⎠  +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                               3                                  4
#                    30 ⎛ 2    ⎞                        28 ⎛ 2    ⎞
# 10457128674263040⋅x  ⋅⎝x  - 1⎠  + 142151592915763200⋅x  ⋅⎝x  - 1⎠  + 107466604
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                        5                                   6
#             26 ⎛ 2    ⎞                         24 ⎛ 2    ⎞
# 2443169792⋅x  ⋅⎝x  - 1⎠  + 4850923108250419200⋅x  ⋅⎝x  - 1⎠  + 136617834477256
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                   7                                    8
#        22 ⎛ 2    ⎞                          20 ⎛ 2    ⎞
# 70400⋅x  ⋅⎝x  - 1⎠  + 24655249815817420800⋅x  ⋅⎝x  - 1⎠  + 2891665101855129600
# ──────────────────────────────────────────────────────────────────────────────
#                                                                           1717
#
#               9                                    10
#    18 ⎛ 2    ⎞                          16 ⎛ 2    ⎞
# 0⋅x  ⋅⎝x  - 1⎠  + 22121238029191741440⋅x  ⋅⎝x  - 1⎠   + 10969208940095078400⋅x
# ──────────────────────────────────────────────────────────────────────────────
# 9869184
#
#            11                                   12
# 14 ⎛ 2    ⎞                          12 ⎛ 2    ⎞                         10 ⎛
#   ⋅⎝x  - 1⎠   + 3465965324821708800⋅x  ⋅⎝x  - 1⎠   + 676786128515481600⋅x  ⋅⎝x
# ──────────────────────────────────────────────────────────────────────────────
#
#
#       13                                14                               15
# 2    ⎞                        8 ⎛ 2    ⎞                       6 ⎛ 2    ⎞
#   - 1⎠   + 77692285161216000⋅x ⋅⎝x  - 1⎠   + 4834186632253440⋅x ⋅⎝x  - 1⎠   +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                            16                            17
#                  4 ⎛ 2    ⎞                    2 ⎛ 2    ⎞                ⎛ 2
# 141626561491800⋅x ⋅⎝x  - 1⎠   + 1470171918600⋅x ⋅⎝x  - 1⎠   + 2268783825⋅⎝x  -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#    18    ⎛
#   ⎞      ⎜             36                  34 ⎛ 2    ⎞                    32 ⎛
#  1⎠    x⋅⎝17179869184⋅x   + 5720896438272⋅x  ⋅⎝x  - 1⎠ + 425491672596480⋅x  ⋅⎝
# ─────, ───────────────────────────────────────────────────────────────────────
#
#
#        2                                 3                                  4
#  2    ⎞                       30 ⎛ 2    ⎞                        28 ⎛ 2    ⎞
# x  - 1⎠  + 12481089062830080⋅x  ⋅⎝x  - 1⎠  + 181365825444249600⋅x  ⋅⎝x  - 1⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                                   5                                   6
#                        26 ⎛ 2    ⎞                         24 ⎛ 2    ⎞
# + 1472690502607306752⋅x  ⋅⎝x  - 1⎠  + 7179366200210620416⋅x  ⋅⎝x  - 1⎠  + 2197
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                              7                                    8
#                   22 ⎛ 2    ⎞                          20 ⎛ 2    ⎞
# 7651633297817600⋅x  ⋅⎝x  - 1⎠  + 43440202056440217600⋅x  ⋅⎝x  - 1⎠  + 56311373
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                          9                                    10
#               18 ⎛ 2    ⎞                          16 ⎛ 2    ⎞
# 036126208000⋅x  ⋅⎝x  - 1⎠  + 48146223945887907840⋅x  ⋅⎝x  - 1⎠   + 27057382052
# ──────────────────────────────────────────────────────────────────────────────
#          17179869184
#
#                       11                                   12
#            14 ⎛ 2    ⎞                          12 ⎛ 2    ⎞
# 234526720⋅x  ⋅⎝x  - 1⎠   + 9864670539877171200⋅x  ⋅⎝x  - 1⎠   + 22764624322793
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                   13                                 14
#        10 ⎛ 2    ⎞                         8 ⎛ 2    ⎞                        6
# 47200⋅x  ⋅⎝x  - 1⎠   + 319401616773888000⋅x ⋅⎝x  - 1⎠   + 25552129341911040⋅x
# ──────────────────────────────────────────────────────────────────────────────
#
#
#          15                               16                             17
#  ⎛ 2    ⎞                       4 ⎛ 2    ⎞                     2 ⎛ 2    ⎞
# ⋅⎝x  - 1⎠   + 1048036555039320⋅x ⋅⎝x  - 1⎠   + 18132120329400⋅x ⋅⎝x  - 1⎠   +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                     18⎞
#             ⎛ 2    ⎞  ⎟               38                   36 ⎛ 2    ⎞
# 83945001525⋅⎝x  - 1⎠  ⎠  34359738368⋅x   + 12077448036352⋅x  ⋅⎝x  - 1⎠ + 95109
# ───────────────────────, ─────────────────────────────────────────────────────
#
#
#                        2                                 3
#             34 ⎛ 2    ⎞                       32 ⎛ 2    ⎞
# 9032862720⋅x  ⋅⎝x  - 1⎠  + 29642586524221440⋅x  ⋅⎝x  - 1⎠  + 45946009112543232
# ──────────────────────────────────────────────────────────────────────────────
#
#
#               4                                   5
#    30 ⎛ 2    ⎞                         28 ⎛ 2    ⎞                          26
# 0⋅x  ⋅⎝x  - 1⎠  + 3997302792791261184⋅x  ⋅⎝x  - 1⎠  + 20985839662154121216⋅x
# ──────────────────────────────────────────────────────────────────────────────
#
#
#          6                                    7
#  ⎛ 2    ⎞                          24 ⎛ 2    ⎞                           22 ⎛
# ⋅⎝x  - 1⎠  + 69595896838776422400⋅x  ⋅⎝x  - 1⎠  + 150066152558611660800⋅x  ⋅⎝x
# ──────────────────────────────────────────────────────────────────────────────
#
#
#       8                                     9
# 2    ⎞                           20 ⎛ 2    ⎞                           18 ⎛ 2
#   - 1⎠  + 213983217537279590400⋅x  ⋅⎝x  - 1⎠  + 203284056660415610880⋅x  ⋅⎝x
# ──────────────────────────────────────────────────────────────────────────────
#                                               34359738368
#
#     10                                     11
#    ⎞                            16 ⎛ 2    ⎞                           14 ⎛ 2
# - 1⎠   + 128522564748114001920⋅x  ⋅⎝x  - 1⎠   + 53551068645047500800⋅x  ⋅⎝x  -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#    12                                    13
#   ⎞                           12 ⎛ 2    ⎞                          10 ⎛ 2    ⎞
#  1⎠   + 14417595404435865600⋅x  ⋅⎝x  - 1⎠   + 2427452287481548800⋅x  ⋅⎝x  - 1⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
# 14                                 15                                16
#                          8 ⎛ 2    ⎞                        6 ⎛ 2    ⎞
#    + 242745228748154880⋅x ⋅⎝x  - 1⎠   + 13275129697164720⋅x ⋅⎝x  - 1⎠   + 3445
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                        17                            18                      1
#              4 ⎛ 2    ⎞                    2 ⎛ 2    ⎞                ⎛ 2    ⎞
# 10286258600⋅x ⋅⎝x  - 1⎠   + 3189910057950⋅x ⋅⎝x  - 1⎠   + 4418157975⋅⎝x  - 1⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
# 9⎤
#  ⎥
#  ⎥
# ─⎥
#  ⎦

# %%
DLegendre
# Out:
# ⎡
# ⎢               2                   ⎛ 2    ⎞                         ⎛     3
# ⎢           15⋅x    3      3   15⋅x⋅⎝x  - 1⎠   4      2 ⎛ 2    ⎞   x⋅⎝112⋅x  +
# ⎢0, 1, 3⋅x, ───── - ─, 10⋅x  + ─────────────, x  + 5⋅x ⋅⎝x  - 1⎠ + ───────────
# ⎣             2     2                2
#
#                               2                                          2
#        ⎛ 2    ⎞⎞      ⎛ 2    ⎞                3 ⎛ 2    ⎞         ⎛ 2    ⎞
#  140⋅x⋅⎝x  - 1⎠⎠   15⋅⎝x  - 1⎠       5   105⋅x ⋅⎝x  - 1⎠   105⋅x⋅⎝x  - 1⎠    6
# ──────────────── + ────────────, 21⋅x  + ─────────────── + ───────────────, x
#   8                     8                       2                 8
#
#                                    2     ⎛
#        4 ⎛ 2    ⎞        2 ⎛ 2    ⎞      ⎜     5         3 ⎛ 2    ⎞         ⎛
#    21⋅x ⋅⎝x  - 1⎠   105⋅x ⋅⎝x  - 1⎠    x⋅⎝432⋅x  + 1512⋅x ⋅⎝x  - 1⎠ + 630⋅x⋅⎝x
#  + ────────────── + ──────────────── + ───────────────────────────────────────
#          2                 8                                  16
#
#       2⎞              3                                           2
# 2    ⎞ ⎟      ⎛ 2    ⎞                                  3 ⎛ 2    ⎞          ⎛
#   - 1⎠ ⎠   35⋅⎝x  - 1⎠       7        5 ⎛ 2    ⎞   315⋅x ⋅⎝x  - 1⎠    315⋅x⋅⎝x
# ──────── + ────────────, 36⋅x  + 189⋅x ⋅⎝x  - 1⎠ + ──────────────── + ────────
#                 16                                        2                  1
#
#       3                                       2                  3     ⎛
# 2    ⎞                              4 ⎛ 2    ⎞         2 ⎛ 2    ⎞      ⎜
#   - 1⎠    8       6 ⎛ 2    ⎞   189⋅x ⋅⎝x  - 1⎠    105⋅x ⋅⎝x  - 1⎠    x⋅⎝5632⋅x
# ───────, x  + 18⋅x ⋅⎝x  - 1⎠ + ──────────────── + ──────────────── + ─────────
# 6                                     4                  4
#
#                                          2                  3⎞               4
# 7          5 ⎛ 2    ⎞          3 ⎛ 2    ⎞           ⎛ 2    ⎞ ⎟       ⎛ 2    ⎞
#   + 38016⋅x ⋅⎝x  - 1⎠ + 44352⋅x ⋅⎝x  - 1⎠  + 9240⋅x⋅⎝x  - 1⎠ ⎠   315⋅⎝x  - 1⎠
# ────────────────────────────────────────────────────────────── + ─────────────
#                          128                                          128
#
#                                             2                   3
#                                   5 ⎛ 2    ⎞          3 ⎛ 2    ⎞           ⎛ 2
#       9        7 ⎛ 2    ⎞   3465⋅x ⋅⎝x  - 1⎠    5775⋅x ⋅⎝x  - 1⎠    3465⋅x⋅⎝x
# , 55⋅x  + 495⋅x ⋅⎝x  - 1⎠ + ───────────────── + ───────────────── + ──────────
#                                     4                   16                128
#
#      4                                        2                   3
#     ⎞             8 ⎛ 2    ⎞        6 ⎛ 2    ⎞          4 ⎛ 2    ⎞          2
#  - 1⎠    10   55⋅x ⋅⎝x  - 1⎠   495⋅x ⋅⎝x  - 1⎠    1155⋅x ⋅⎝x  - 1⎠    5775⋅x ⋅
# ──────, x   + ────────────── + ──────────────── + ───────────────── + ────────
#                     2                 4                   8                  1
#
#         4     ⎛                                                  2
# ⎛ 2    ⎞      ⎜       9           7 ⎛ 2    ⎞           5 ⎛ 2    ⎞            3
# ⎝x  - 1⎠    x⋅⎝16640⋅x  + 183040⋅x ⋅⎝x  - 1⎠ + 411840⋅x ⋅⎝x  - 1⎠  + 240240⋅x
# ───────── + ──────────────────────────────────────────────────────────────────
# 28                                                         256
#
#          3                   4⎞               5
#  ⎛ 2    ⎞            ⎛ 2    ⎞ ⎟       ⎛ 2    ⎞                  9 ⎛ 2    ⎞
# ⋅⎝x  - 1⎠  + 30030⋅x⋅⎝x  - 1⎠ ⎠   693⋅⎝x  - 1⎠       11   2145⋅x ⋅⎝x  - 1⎠   6
# ─────────────────────────────── + ─────────────, 78⋅x   + ──────────────── + ─
#                                        256                       2
#
#                2                    3                    4                  5
#      7 ⎛ 2    ⎞           5 ⎛ 2    ⎞           3 ⎛ 2    ⎞           ⎛ 2    ⎞
# 435⋅x ⋅⎝x  - 1⎠    45045⋅x ⋅⎝x  - 1⎠    45045⋅x ⋅⎝x  - 1⎠    9009⋅x⋅⎝x  - 1⎠
# ──────────────── + ────────────────── + ────────────────── + ────────────────,
#        2                   16                   64                 256
#
#                                          2                   3
#                                8 ⎛ 2    ⎞          6 ⎛ 2    ⎞           4 ⎛ 2
#   12       10 ⎛ 2    ⎞   2145⋅x ⋅⎝x  - 1⎠    2145⋅x ⋅⎝x  - 1⎠    45045⋅x ⋅⎝x
#  x   + 39⋅x  ⋅⎝x  - 1⎠ + ───────────────── + ───────────────── + ─────────────
#                                  8                   4                  128
#
#     4                   5     ⎛
#    ⎞          2 ⎛ 2    ⎞      ⎜       11            9 ⎛ 2    ⎞            7 ⎛
# - 1⎠    9009⋅x ⋅⎝x  - 1⎠    x⋅⎝92160⋅x   + 1497600⋅x ⋅⎝x  - 1⎠ + 5491200⋅x ⋅⎝x
# ───── + ───────────────── + ──────────────────────────────────────────────────
#                128
#
#       2                      3                      4                    5⎞
# 2    ⎞             5 ⎛ 2    ⎞             3 ⎛ 2    ⎞             ⎛ 2    ⎞ ⎟
#   - 1⎠  + 6177600⋅x ⋅⎝x  - 1⎠  + 2162160⋅x ⋅⎝x  - 1⎠  + 180180⋅x⋅⎝x  - 1⎠ ⎠
# ─────────────────────────────────────────────────────────────────────────── +
#            1024
#
#              6                                                 2
#      ⎛ 2    ⎞                   11 ⎛ 2    ⎞          9 ⎛ 2    ⎞            7 ⎛
# 3003⋅⎝x  - 1⎠        13   4095⋅x  ⋅⎝x  - 1⎠   75075⋅x ⋅⎝x  - 1⎠    225225⋅x ⋅⎝
# ──────────────, 105⋅x   + ───────────────── + ────────────────── + ───────────
#      1024                         2                   8                     16
#
#        3                     4                     5                   6
#  2    ⎞            5 ⎛ 2    ⎞            3 ⎛ 2    ⎞            ⎛ 2    ⎞
# x  - 1⎠    945945⋅x ⋅⎝x  - 1⎠    315315⋅x ⋅⎝x  - 1⎠    45045⋅x⋅⎝x  - 1⎠    14
# ──────── + ─────────────────── + ─────────────────── + ─────────────────, x
#                    128                   256                  1024
#
#                                       2                    3
#        12 ⎛ 2    ⎞         10 ⎛ 2    ⎞           8 ⎛ 2    ⎞            6 ⎛ 2
#   105⋅x  ⋅⎝x  - 1⎠   4095⋅x  ⋅⎝x  - 1⎠    25025⋅x ⋅⎝x  - 1⎠    225225⋅x ⋅⎝x  -
# + ──────────────── + ────────────────── + ────────────────── + ───────────────
#          2                   8                    16                   128
#
#    4                     5                     6     ⎛
#   ⎞            4 ⎛ 2    ⎞            2 ⎛ 2    ⎞      ⎜        13            11
#  1⎠    189189⋅x ⋅⎝x  - 1⎠    105105⋅x ⋅⎝x  - 1⎠    x⋅⎝243712⋅x   + 5483520⋅x
# ──── + ─────────────────── + ─────────────────── + ───────────────────────────
#                256                   1024
#
#                                 2                       3
#  ⎛ 2    ⎞             9 ⎛ 2    ⎞              7 ⎛ 2    ⎞              5 ⎛ 2
# ⋅⎝x  - 1⎠ + 29702400⋅x ⋅⎝x  - 1⎠  + 54454400⋅x ⋅⎝x  - 1⎠  + 36756720⋅x ⋅⎝x  -
# ──────────────────────────────────────────────────────────────────────────────
#                                                 2048
#
#   4                      5                    6⎞                7
#  ⎞             3 ⎛ 2    ⎞             ⎛ 2    ⎞ ⎟        ⎛ 2    ⎞
# 1⎠  + 8576568⋅x ⋅⎝x  - 1⎠  + 510510⋅x⋅⎝x  - 1⎠ ⎠   6435⋅⎝x  - 1⎠        15
# ──────────────────────────────────────────────── + ──────────────, 136⋅x   + 3
#                                                         2048
#
#                                                            3
#                                      2           9 ⎛ 2    ⎞            7 ⎛ 2
#      13 ⎛ 2    ⎞          11 ⎛ 2    ⎞    425425⋅x ⋅⎝x  - 1⎠    765765⋅x ⋅⎝x  -
# 570⋅x  ⋅⎝x  - 1⎠ + 23205⋅x  ⋅⎝x  - 1⎠  + ─────────────────── + ───────────────
#                                                   8                     16
#
#    4                      5                     6                    7
#   ⎞             5 ⎛ 2    ⎞            3 ⎛ 2    ⎞             ⎛ 2    ⎞
#  1⎠    1072071⋅x ⋅⎝x  - 1⎠    255255⋅x ⋅⎝x  - 1⎠    109395⋅x⋅⎝x  - 1⎠    16
# ──── + ──────────────────── + ─────────────────── + ──────────────────, x   +
#                 64                    128                  2048
#
#                                    2                    3
#                         12 ⎛ 2    ⎞          10 ⎛ 2    ⎞            8 ⎛ 2    ⎞
#     14 ⎛ 2    ⎞   1785⋅x  ⋅⎝x  - 1⎠    7735⋅x  ⋅⎝x  - 1⎠    425425⋅x ⋅⎝x  - 1⎠
# 68⋅x  ⋅⎝x  - 1⎠ + ────────────────── + ────────────────── + ──────────────────
#                           2                    2                     64
#
# 4                     5                     6                    7     ⎛
#             6 ⎛ 2    ⎞            4 ⎛ 2    ⎞           2 ⎛ 2    ⎞      ⎜
#     153153⋅x ⋅⎝x  - 1⎠    357357⋅x ⋅⎝x  - 1⎠    36465⋅x ⋅⎝x  - 1⎠    x⋅⎝498073
# ─ + ─────────────────── + ─────────────────── + ────────────────── + ─────────
#              32                   256                  256
#
#                                                         2
#    15              13 ⎛ 2    ⎞               11 ⎛ 2    ⎞                9 ⎛ 2
# 6⋅x   + 148176896⋅x  ⋅⎝x  - 1⎠ + 1111326720⋅x  ⋅⎝x  - 1⎠  + 3009843200⋅x ⋅⎝x
# ──────────────────────────────────────────────────────────────────────────────
#
#
#     3                         4                         5
#    ⎞                7 ⎛ 2    ⎞                5 ⎛ 2    ⎞               3 ⎛ 2
# - 1⎠  + 3310827520⋅x ⋅⎝x  - 1⎠  + 1489872384⋅x ⋅⎝x  - 1⎠  + 248312064⋅x ⋅⎝x  -
# ──────────────────────────────────────────────────────────────────────────────
#        32768
#
#    6                      7⎞                  8
#   ⎞               ⎛ 2    ⎞ ⎟          ⎛ 2    ⎞
#  1⎠  + 11085360⋅x⋅⎝x  - 1⎠ ⎠   109395⋅⎝x  - 1⎠        17         15 ⎛ 2    ⎞
# ──────────────────────────── + ────────────────, 171⋅x   + 5814⋅x  ⋅⎝x  - 1⎠ +
#                                     32768
#
#                     2                       3                       4
#          13 ⎛ 2    ⎞             11 ⎛ 2    ⎞              9 ⎛ 2    ⎞
#  101745⋅x  ⋅⎝x  - 1⎠    1322685⋅x  ⋅⎝x  - 1⎠    14549535⋅x ⋅⎝x  - 1⎠    872972
#  ──────────────────── + ───────────────────── + ───────────────────── + ──────
#           2                       8                       64
#
#              5                      6                      7
#    7 ⎛ 2    ⎞             5 ⎛ 2    ⎞             3 ⎛ 2    ⎞              ⎛ 2
# 1⋅x ⋅⎝x  - 1⎠    8729721⋅x ⋅⎝x  - 1⎠    6235515⋅x ⋅⎝x  - 1⎠    2078505⋅x⋅⎝x  -
# ────────────── + ──────────────────── + ──────────────────── + ───────────────
#    64                    256                    2048                  32768
#
#    8                                            2                     3
#   ⎞              16 ⎛ 2    ⎞         14 ⎛ 2    ⎞           12 ⎛ 2    ⎞
#  1⎠    18   171⋅x  ⋅⎝x  - 1⎠   2907⋅x  ⋅⎝x  - 1⎠    33915⋅x  ⋅⎝x  - 1⎠    1322
# ────, x   + ──────────────── + ────────────────── + ─────────────────── + ────
#                    2                   2                     4
#
#                 4                      5                      6
#      10 ⎛ 2    ⎞             8 ⎛ 2    ⎞             6 ⎛ 2    ⎞             4 ⎛
# 685⋅x  ⋅⎝x  - 1⎠    2909907⋅x ⋅⎝x  - 1⎠    2909907⋅x ⋅⎝x  - 1⎠    1247103⋅x ⋅⎝
# ───────────────── + ──────────────────── + ──────────────────── + ────────────
#       64                    128                    256                    512
#
#        7                      8     ⎛
#  2    ⎞             2 ⎛ 2    ⎞      ⎜          17              15 ⎛ 2    ⎞
# x  - 1⎠    6235515⋅x ⋅⎝x  - 1⎠    x⋅⎝12386304⋅x   + 470679552⋅x  ⋅⎝x  - 1⎠ + 4
# ──────── + ──────────────────── + ────────────────────────────────────────────
#                   32768
#
#                       2                           3                          4
#            13 ⎛ 2    ⎞                 11 ⎛ 2    ⎞                 9 ⎛ 2    ⎞
# 667572224⋅x  ⋅⎝x  - 1⎠  + 17503395840⋅x  ⋅⎝x  - 1⎠  + 28443018240⋅x ⋅⎝x  - 1⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                                                  65536
#
#                           5                         6                        7
#                 7 ⎛ 2    ⎞                5 ⎛ 2    ⎞               3 ⎛ 2    ⎞
#  + 20858213376⋅x ⋅⎝x  - 1⎠  + 6704425728⋅x ⋅⎝x  - 1⎠  + 838053216⋅x ⋅⎝x  - 1⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                       8⎞                  9
#               ⎛ 2    ⎞ ⎟          ⎛ 2    ⎞                    17 ⎛ 2    ⎞
#  + 29099070⋅x⋅⎝x  - 1⎠ ⎠   230945⋅⎝x  - 1⎠        19   17955⋅x  ⋅⎝x  - 1⎠
# ──────────────────────── + ────────────────, 210⋅x   + ────────────────── + 10
#                                 65536                          2
#
#                                          3                        4
#                  2            13 ⎛ 2    ⎞              11 ⎛ 2    ⎞
#       15 ⎛ 2    ⎞    3561075⋅x  ⋅⎝x  - 1⎠    27776385⋅x  ⋅⎝x  - 1⎠    10184674
# 1745⋅x  ⋅⎝x  - 1⎠  + ───────────────────── + ────────────────────── + ────────
#                                8                       32
#
#              5                       6                        7
#    9 ⎛ 2    ⎞              7 ⎛ 2    ⎞               5 ⎛ 2    ⎞              3
# 5⋅x ⋅⎝x  - 1⎠    43648605⋅x ⋅⎝x  - 1⎠    130945815⋅x ⋅⎝x  - 1⎠    72747675⋅x ⋅
# ────────────── + ───────────────────── + ────────────────────── + ────────────
#  128                      128                     2048                    1638
#
#         8                     9                                             2
# ⎛ 2    ⎞              ⎛ 2    ⎞                                   16 ⎛ 2    ⎞
# ⎝x  - 1⎠    4849845⋅x⋅⎝x  - 1⎠    20        18 ⎛ 2    ⎞   17955⋅x  ⋅⎝x  - 1⎠
# ───────── + ───────────────────, x   + 105⋅x  ⋅⎝x  - 1⎠ + ───────────────────
# 4                  65536                                           8
#
#                     3                       4                       5
#          14 ⎛ 2    ⎞             12 ⎛ 2    ⎞             10 ⎛ 2    ⎞
#   33915⋅x  ⋅⎝x  - 1⎠    3561075⋅x  ⋅⎝x  - 1⎠    5555277⋅x  ⋅⎝x  - 1⎠    339489
# + ─────────────────── + ───────────────────── + ───────────────────── + ──────
#            2                      64                      64
#
#               6                      7                        8
#     8 ⎛ 2    ⎞             6 ⎛ 2    ⎞               4 ⎛ 2    ⎞             2 ⎛
# 15⋅x ⋅⎝x  - 1⎠    6235515⋅x ⋅⎝x  - 1⎠    130945815⋅x ⋅⎝x  - 1⎠    8083075⋅x ⋅⎝
# ─────────────── + ──────────────────── + ────────────────────── + ────────────
#    512                    256                    32768                   32768
#
#        9     ⎛
#  2    ⎞      ⎜          19               17 ⎛ 2    ⎞                15 ⎛ 2
# x  - 1⎠    x⋅⎝60293120⋅x   + 2848849920⋅x  ⋅⎝x  - 1⎠ + 36085432320⋅x  ⋅⎝x  - 1
# ──────── + ───────────────────────────────────────────────────────────────────
#
#
#  2                            3                            4
# ⎞                  13 ⎛ 2    ⎞                  11 ⎛ 2    ⎞                  9
# ⎠  + 178923601920⋅x  ⋅⎝x  - 1⎠  + 402578104320⋅x  ⋅⎝x  - 1⎠  + 436126279680⋅x
# ──────────────────────────────────────────────────────────────────────────────
#                                                              262144
#
#          5                           6                          7
#  ⎛ 2    ⎞                  7 ⎛ 2    ⎞                 5 ⎛ 2    ⎞
# ⋅⎝x  - 1⎠  + 228447098880⋅x ⋅⎝x  - 1⎠  + 55072068480⋅x ⋅⎝x  - 1⎠  + 5354228880
# ──────────────────────────────────────────────────────────────────────────────
#
#
#             8                       9⎞                  10
#   3 ⎛ 2    ⎞                ⎛ 2    ⎞ ⎟          ⎛ 2    ⎞                     1
# ⋅x ⋅⎝x  - 1⎠  + 148728580⋅x⋅⎝x  - 1⎠ ⎠   969969⋅⎝x  - 1⎠         21   26565⋅x
# ────────────────────────────────────── + ─────────────────, 253⋅x   + ────────
#                                                262144
#
#                                  2                       3
# 9 ⎛ 2    ⎞            17 ⎛ 2    ⎞             15 ⎛ 2    ⎞               13 ⎛ 2
#  ⋅⎝x  - 1⎠   1514205⋅x  ⋅⎝x  - 1⎠    8580495⋅x  ⋅⎝x  - 1⎠    180190395⋅x  ⋅⎝x
# ────────── + ───────────────────── + ───────────────────── + ─────────────────
# 2                      8                       8                        64
#
#      4                         5                         6
#     ⎞               11 ⎛ 2    ⎞                9 ⎛ 2    ⎞                7 ⎛ 2
#  - 1⎠    468495027⋅x  ⋅⎝x  - 1⎠    1227010785⋅x ⋅⎝x  - 1⎠    1577585295⋅x ⋅⎝x
# ────── + ─────────────────────── + ─────────────────────── + ─────────────────
#                    128                       512                       2048
#
#      7                         8                        9
#     ⎞                5 ⎛ 2    ⎞               3 ⎛ 2    ⎞               ⎛ 2
#  - 1⎠    3681032355⋅x ⋅⎝x  - 1⎠    409003595⋅x ⋅⎝x  - 1⎠    22309287⋅x⋅⎝x  - 1
# ────── + ─────────────────────── + ────────────────────── + ──────────────────
#                   32768                    65536                    262144
#
#  10                                             2                      3
# ⎞               20 ⎛ 2    ⎞          18 ⎛ 2    ⎞            16 ⎛ 2    ⎞
# ⎠     22   253⋅x  ⋅⎝x  - 1⎠   26565⋅x  ⋅⎝x  - 1⎠    504735⋅x  ⋅⎝x  - 1⎠    858
# ───, x   + ──────────────── + ─────────────────── + ──────────────────── + ───
#                   2                    8                     16
#
#                  4                        5                         6
#       14 ⎛ 2    ⎞              12 ⎛ 2    ⎞               10 ⎛ 2    ⎞
# 0495⋅x  ⋅⎝x  - 1⎠    36038079⋅x  ⋅⎝x  - 1⎠    156165009⋅x  ⋅⎝x  - 1⎠    175287
# ────────────────── + ────────────────────── + ─────────────────────── + ──────
#        64                     128                       512
#
#                7                         8                        9
#      8 ⎛ 2    ⎞                6 ⎛ 2    ⎞               4 ⎛ 2    ⎞
# 255⋅x ⋅⎝x  - 1⎠    1577585295⋅x ⋅⎝x  - 1⎠    409003595⋅x ⋅⎝x  - 1⎠    81800719
# ──────────────── + ─────────────────────── + ────────────────────── + ────────
#    1024                     32768                    65536
#
#             10     ⎛
#   2 ⎛ 2    ⎞       ⎜           21               19 ⎛ 2    ⎞                 17
# ⋅x ⋅⎝x  - 1⎠     x⋅⎝144179200⋅x   + 8290304000⋅x  ⋅⎝x  - 1⎠ + 130572288000⋅x
# ────────────── + ─────────────────────────────────────────────────────────────
# 262144
#
#          2                            3                             4
#  ⎛ 2    ⎞                  15 ⎛ 2    ⎞                   13 ⎛ 2    ⎞
# ⋅⎝x  - 1⎠  + 826957824000⋅x  ⋅⎝x  - 1⎠  + 2460199526400⋅x  ⋅⎝x  - 1⎠  + 369029
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                     5                            6
#          11 ⎛ 2    ⎞                   9 ⎛ 2    ⎞                   7 ⎛ 2    ⎞
# 9289600⋅x  ⋅⎝x  - 1⎠  + 2855588736000⋅x ⋅⎝x  - 1⎠  + 1121838432000⋅x ⋅⎝x  - 1⎠
# ──────────────────────────────────────────────────────────────────────────────
#         524288
#
# 7                           8                          9
#                   5 ⎛ 2    ⎞                 3 ⎛ 2    ⎞                ⎛ 2
#   + 210344706000⋅x ⋅⎝x  - 1⎠  + 16360143800⋅x ⋅⎝x  - 1⎠  + 371821450⋅x⋅⎝x  - 1
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  10⎞                   11                                                    2
# ⎞  ⎟           ⎛ 2    ⎞                                           19 ⎛ 2    ⎞
# ⎠  ⎠   2028117⋅⎝x  - 1⎠         23          21 ⎛ 2    ⎞   664125⋅x  ⋅⎝x  - 1⎠
# ──── + ──────────────────, 300⋅x   + 18975⋅x  ⋅⎝x  - 1⎠ + ────────────────────
#              524288                                                2
#
#                         3                         4                         5
#              17 ⎛ 2    ⎞               15 ⎛ 2    ⎞               13 ⎛ 2    ⎞
#    37855125⋅x  ⋅⎝x  - 1⎠    128707425⋅x  ⋅⎝x  - 1⎠    900951975⋅x  ⋅⎝x  - 1⎠
#  + ────────────────────── + ─────────────────────── + ───────────────────────
#              16                        16                        64
#
#                          6                          7
#               11 ⎛ 2    ⎞                 9 ⎛ 2    ⎞                 7 ⎛ 2
#   1673196525⋅x  ⋅⎝x  - 1⎠    13146544125⋅x ⋅⎝x  - 1⎠    13146544125⋅x ⋅⎝x  - 1
# + ──────────────────────── + ──────────────────────── + ──────────────────────
#             128                        2048                       8192
#
#  8                         9                        10                      11
# ⎞                5 ⎛ 2    ⎞               3 ⎛ 2    ⎞                ⎛ 2    ⎞
# ⎠    6135053925⋅x ⋅⎝x  - 1⎠    557732175⋅x ⋅⎝x  - 1⎠     50702925⋅x⋅⎝x  - 1⎠
# ── + ─────────────────────── + ─────────────────────── + ─────────────────────
#               32768                     65536                    524288
#
#                                              2                      3
#                                   20 ⎛ 2    ⎞            18 ⎛ 2    ⎞
#    24        22 ⎛ 2    ⎞   18975⋅x  ⋅⎝x  - 1⎠    221375⋅x  ⋅⎝x  - 1⎠    378551
# , x   + 150⋅x  ⋅⎝x  - 1⎠ + ─────────────────── + ──────────────────── + ──────
#                                     4                     4
#
#                4                        5                         6
#     16 ⎛ 2    ⎞              14 ⎛ 2    ⎞               12 ⎛ 2    ⎞
# 25⋅x  ⋅⎝x  - 1⎠    25741485⋅x  ⋅⎝x  - 1⎠    300317325⋅x  ⋅⎝x  - 1⎠    23902807
# ──────────────── + ────────────────────── + ─────────────────────── + ────────
#    128                       32                       256
#
#               7                          8                         9
#    10 ⎛ 2    ⎞                 8 ⎛ 2    ⎞                6 ⎛ 2    ⎞
# 5⋅x  ⋅⎝x  - 1⎠    13146544125⋅x ⋅⎝x  - 1⎠    1460727125⋅x ⋅⎝x  - 1⎠    1227010
# ─────────────── + ──────────────────────── + ─────────────────────── + ───────
#   256                      32768                      16384
#
#                10                       11     ⎛
#      4 ⎛ 2    ⎞               2 ⎛ 2    ⎞       ⎜            23
# 785⋅x ⋅⎝x  - 1⎠     50702925⋅x ⋅⎝x  - 1⎠     x⋅⎝1358954496⋅x   + 93428121600⋅x
# ───────────────── + ────────────────────── + ─────────────────────────────────
#   131072                    131072
#
#                                         2                              3
# 21 ⎛ 2    ⎞                  19 ⎛ 2    ⎞                    17 ⎛ 2    ⎞
#   ⋅⎝x  - 1⎠ + 1790705664000⋅x  ⋅⎝x  - 1⎠  + 14101807104000⋅x  ⋅⎝x  - 1⎠  + 535
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                         4                               5
#              15 ⎛ 2    ⎞                     13 ⎛ 2    ⎞                     1
# 86866995200⋅x  ⋅⎝x  - 1⎠  + 106280619540480⋅x  ⋅⎝x  - 1⎠  + 113872092364800⋅x
# ──────────────────────────────────────────────────────────────────────────────
#                                                           4194304
#
#           6                             7                             8
# 1 ⎛ 2    ⎞                    9 ⎛ 2    ⎞                    7 ⎛ 2    ⎞
#  ⋅⎝x  - 1⎠  + 66086482176000⋅x ⋅⎝x  - 1⎠  + 20193091776000⋅x ⋅⎝x  - 1⎠  + 3028
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                      9                           10                        11⎞
#            5 ⎛ 2    ⎞                  3 ⎛ 2    ⎞                  ⎛ 2    ⎞  ⎟
# 963766400⋅x ⋅⎝x  - 1⎠  + 192752239680⋅x ⋅⎝x  - 1⎠   + 3650610600⋅x⋅⎝x  - 1⎠  ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                     12                                                     2
#             ⎛ 2    ⎞                                            21 ⎛ 2    ⎞
#    16900975⋅⎝x  - 1⎠         25          23 ⎛ 2    ⎞   2220075⋅x  ⋅⎝x  - 1⎠
#  + ───────────────────, 351⋅x   + 26325⋅x  ⋅⎝x  - 1⎠ + ───────────────────── +
#          4194304                                                 4
#
#                       3                          4                          5
#            19 ⎛ 2    ⎞                17 ⎛ 2    ⎞                15 ⎛ 2    ⎞
#  77702625⋅x  ⋅⎝x  - 1⎠    2657429775⋅x  ⋅⎝x  - 1⎠    3011753745⋅x  ⋅⎝x  - 1⎠
#  ────────────────────── + ──────────────────────── + ────────────────────────
#            16                       128                         64
#
#                           6                           7
#                13 ⎛ 2    ⎞                 11 ⎛ 2    ⎞                  9 ⎛ 2
#   15058768725⋅x  ⋅⎝x  - 1⎠    83898854325⋅x  ⋅⎝x  - 1⎠    512715220875⋅x ⋅⎝x
# + ───────────────────────── + ───────────────────────── + ────────────────────
#              256                         2048                       32768
#
#     8                           9                          10
#    ⎞                  7 ⎛ 2    ⎞                 5 ⎛ 2    ⎞                 3
# - 1⎠    102543044175⋅x ⋅⎝x  - 1⎠    39152798685⋅x ⋅⎝x  - 1⎠     5932242225⋅x ⋅
# ───── + ───────────────────────── + ───────────────────────── + ──────────────
#                   32768                       131072                     52428
#
#         11                       12
# ⎛ 2    ⎞                 ⎛ 2    ⎞               24 ⎛ 2    ⎞          22 ⎛ 2
# ⎝x  - 1⎠     456326325⋅x⋅⎝x  - 1⎠     26   351⋅x  ⋅⎝x  - 1⎠   26325⋅x  ⋅⎝x  -
# ────────── + ──────────────────────, x   + ──────────────── + ────────────────
# 8                   4194304                       2                    4
#
#   2                      3                        4                         5
#  ⎞            20 ⎛ 2    ⎞              18 ⎛ 2    ⎞               16 ⎛ 2    ⎞
# 1⎠    740025⋅x  ⋅⎝x  - 1⎠    77702625⋅x  ⋅⎝x  - 1⎠    531485955⋅x  ⋅⎝x  - 1⎠
# ─── + ──────────────────── + ────────────────────── + ───────────────────────
#                8                      128                       256
#
#                          6                          7
#               14 ⎛ 2    ⎞                12 ⎛ 2    ⎞                 10 ⎛ 2
#   1003917915⋅x  ⋅⎝x  - 1⎠    2151252675⋅x  ⋅⎝x  - 1⎠    83898854325⋅x  ⋅⎝x  -
# + ──────────────────────── + ──────────────────────── + ──────────────────────
#             256                        512                        32768
#
#   8                          9                          10
#  ⎞                 8 ⎛ 2    ⎞                 6 ⎛ 2    ⎞                 4 ⎛ 2
# 1⎠    56968357875⋅x ⋅⎝x  - 1⎠    20508608835⋅x ⋅⎝x  - 1⎠     3559345335⋅x ⋅⎝x
# ─── + ──────────────────────── + ───────────────────────── + ─────────────────
#                65536                       131072                     262144
#
#      11                         12     ⎛
#     ⎞                 2 ⎛ 2    ⎞       ⎜            25                 23 ⎛ 2
#  - 1⎠     1977414075⋅x ⋅⎝x  - 1⎠     x⋅⎝3162505216⋅x   + 256162922496⋅x  ⋅⎝x
# ─────── + ──────────────────────── + ─────────────────────────────────────────
#                   4194304
#
#                                  2                              3
#    ⎞                  21 ⎛ 2    ⎞                    19 ⎛ 2    ⎞
# - 1⎠ + 5870400307200⋅x  ⋅⎝x  - 1⎠  + 56258002944000⋅x  ⋅⎝x  - 1⎠  + 2658190639
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                   4                               5
#        17 ⎛ 2    ⎞                     15 ⎛ 2    ⎞                     13 ⎛ 2
# 10400⋅x  ⋅⎝x  - 1⎠  + 673408295239680⋅x  ⋅⎝x  - 1⎠  + 953995084922880⋅x  ⋅⎝x
# ──────────────────────────────────────────────────────────────────────────────
#                                                                     8388608
#
#     6                               7                              8
#    ⎞                     11 ⎛ 2    ⎞                     9 ⎛ 2    ⎞
# - 1⎠  + 766603193241600⋅x  ⋅⎝x  - 1⎠  + 346036163616000⋅x ⋅⎝x  - 1⎠  + 8458661
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                    9                             10
#          7 ⎛ 2    ⎞                    5 ⎛ 2    ⎞                   3 ⎛ 2    ⎞
# 7772800⋅x ⋅⎝x  - 1⎠  + 10381084908480⋅x ⋅⎝x  - 1⎠   + 550512078480⋅x ⋅⎝x  - 1⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
# 11                        12⎞                    13
#                   ⎛ 2    ⎞  ⎟            ⎛ 2    ⎞                     25 ⎛ 2
#    + 8822308950⋅x⋅⎝x  - 1⎠  ⎠   35102025⋅⎝x  - 1⎠         27   71253⋅x  ⋅⎝x  -
# ───────────────────────────── + ───────────────────, 406⋅x   + ───────────────
#                                       8388608                          2
#
#                           2                         3
#   ⎞            23 ⎛ 2    ⎞               21 ⎛ 2    ⎞                19 ⎛ 2
#  1⎠   1781325⋅x  ⋅⎝x  - 1⎠    150225075⋅x  ⋅⎝x  - 1⎠    3154726575⋅x  ⋅⎝x  - 1
# ─── + ───────────────────── + ─────────────────────── + ──────────────────────
#                 2                        16                        64
#
#  4                           5                           6
# ⎞                 17 ⎛ 2    ⎞                 15 ⎛ 2    ⎞                  13
# ⎠    35963882955⋅x  ⋅⎝x  - 1⎠    29113619535⋅x  ⋅⎝x  - 1⎠    436704293025⋅x  ⋅
# ── + ───────────────────────── + ───────────────────────── + ─────────────────
#                 256                         128                         2048
#
#         7                             8                            9
# ⎛ 2    ⎞                   11 ⎛ 2    ⎞                   9 ⎛ 2    ⎞
# ⎝x  - 1⎠    1892385269775⋅x  ⋅⎝x  - 1⎠    2312915329725⋅x ⋅⎝x  - 1⎠    3784770
# ───────── + ─────────────────────────── + ────────────────────────── + ───────
#                        16384                        65536
#
#                  10                           11                          12
#        7 ⎛ 2    ⎞                   5 ⎛ 2    ⎞                  3 ⎛ 2    ⎞
# 53955⋅x ⋅⎝x  - 1⎠     240849034335⋅x ⋅⎝x  - 1⎠     30878081325⋅x ⋅⎝x  - 1⎠
# ─────────────────── + ────────────────────────── + ───────────────────────── +
#    65536                        524288                      2097152
#
#                       13                                             2
#               ⎛ 2    ⎞                                    24 ⎛ 2    ⎞
#  1017958725⋅x⋅⎝x  - 1⎠     28        26 ⎛ 2    ⎞   71253⋅x  ⋅⎝x  - 1⎠    59377
#  ───────────────────────, x   + 203⋅x  ⋅⎝x  - 1⎠ + ─────────────────── + ─────
#          8388608                                            8
#
#               3                         4                         5
#    22 ⎛ 2    ⎞               20 ⎛ 2    ⎞               18 ⎛ 2    ⎞
# 5⋅x  ⋅⎝x  - 1⎠    150225075⋅x  ⋅⎝x  - 1⎠    630945315⋅x  ⋅⎝x  - 1⎠    11987960
# ─────────────── + ─────────────────────── + ─────────────────────── + ────────
#     4                       128                       128
#
#                 6                          7                            8
#      16 ⎛ 2    ⎞                14 ⎛ 2    ⎞                  12 ⎛ 2    ⎞
# 985⋅x  ⋅⎝x  - 1⎠    4159088505⋅x  ⋅⎝x  - 1⎠    436704293025⋅x  ⋅⎝x  - 1⎠    21
# ───────────────── + ──────────────────────── + ────────────────────────── + ──
#    1024                       256                        32768
#
#                        9                           10
#             10 ⎛ 2    ⎞                  8 ⎛ 2    ⎞                  6 ⎛ 2
# 0265029975⋅x  ⋅⎝x  - 1⎠    462583065945⋅x ⋅⎝x  - 1⎠     34407004905⋅x ⋅⎝x  - 1
# ──────────────────────── + ────────────────────────── + ──────────────────────
#         32768                        262144                       131072
#
#  11                          12                         13     ⎛
# ⎞                  4 ⎛ 2    ⎞                 2 ⎛ 2    ⎞       ⎜             2
# ⎠     80283011445⋅x ⋅⎝x  - 1⎠     2375237025⋅x ⋅⎝x  - 1⎠     x⋅⎝14562623488⋅x
# ─── + ───────────────────────── + ──────────────────────── + ─────────────────
#                4194304                    4194304
#
#                                                             2
# 7                  25 ⎛ 2    ⎞                   23 ⎛ 2    ⎞
#   + 1372527263744⋅x  ⋅⎝x  - 1⎠ + 37058236121088⋅x  ⋅⎝x  - 1⎠  + 42462562222080
# ──────────────────────────────────────────────────────────────────────────────
#
#
#               3                                4
#    21 ⎛ 2    ⎞                      19 ⎛ 2    ⎞                      17 ⎛ 2
# 0⋅x  ⋅⎝x  - 1⎠  + 2441597327769600⋅x  ⋅⎝x  - 1⎠  + 7691031582474240⋅x  ⋅⎝x  -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#   5                                 6                                 7
#  ⎞                       15 ⎛ 2    ⎞                       13 ⎛ 2    ⎞
# 1⎠  + 13917104768286720⋅x  ⋅⎝x  - 1⎠  + 14786923816304640⋅x  ⋅⎝x  - 1⎠  + 9241
# ──────────────────────────────────────────────────────────────────────────────
#                                       33554432
#
#                          8                               9
#               11 ⎛ 2    ⎞                      9 ⎛ 2    ⎞
# 827385190400⋅x  ⋅⎝x  - 1⎠  + 3337326555763200⋅x ⋅⎝x  - 1⎠  + 667465311152640⋅x
# ──────────────────────────────────────────────────────────────────────────────
#
#
#           10                             11                            12
# 7 ⎛ 2    ⎞                     5 ⎛ 2    ⎞                    3 ⎛ 2    ⎞
#  ⋅⎝x  - 1⎠   + 68263497731520⋅x ⋅⎝x  - 1⎠   + 3063105667440⋅x ⋅⎝x  - 1⎠   + 42
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                     13⎞                     14
#             ⎛ 2    ⎞  ⎟             ⎛ 2    ⎞                     27 ⎛ 2    ⎞
# 075627300⋅x⋅⎝x  - 1⎠  ⎠   145422675⋅⎝x  - 1⎠         29   94395⋅x  ⋅⎝x  - 1⎠
# ─────────────────────── + ────────────────────, 465⋅x   + ────────────────── +
#                                 33554432                          2
#
#                       2                         3                           4
#            25 ⎛ 2    ⎞               23 ⎛ 2    ⎞                 21 ⎛ 2    ⎞
#  11044215⋅x  ⋅⎝x  - 1⎠    276105375⋅x  ⋅⎝x  - 1⎠    13970931975⋅x  ⋅⎝x  - 1⎠
#  ────────────────────── + ─────────────────────── + ─────────────────────────
#            8                         16                        128
#
#                           5                            6
#                19 ⎛ 2    ⎞                  17 ⎛ 2    ⎞                   15 ⎛
#   97796523825⋅x  ⋅⎝x  - 1⎠    796343122575⋅x  ⋅⎝x  - 1⎠    1933976154825⋅x  ⋅⎝
# + ───────────────────────── + ────────────────────────── + ───────────────────
#              256                         1024                          2048
#
#        7                              8                              9
#  2    ⎞                    13 ⎛ 2    ⎞                    11 ⎛ 2    ⎞
# x  - 1⎠    22563055139625⋅x  ⋅⎝x  - 1⎠    19554647787675⋅x  ⋅⎝x  - 1⎠    19554
# ──────── + ──────────────────────────── + ──────────────────────────── + ─────
#                       32768                          65536
#
#                      10                            11
#            9 ⎛ 2    ⎞                    7 ⎛ 2    ⎞                    5 ⎛ 2
# 647787675⋅x ⋅⎝x  - 1⎠     5333085760275⋅x ⋅⎝x  - 1⎠     2871661563225⋅x ⋅⎝x  -
# ─────────────────────── + ─────────────────────────── + ──────────────────────
#       262144                         524288                       4194304
#
#    12                           13                        14
#   ⎞                   3 ⎛ 2    ⎞                  ⎛ 2    ⎞               28 ⎛
#  1⎠     157783602375⋅x ⋅⎝x  - 1⎠     4508102925⋅x⋅⎝x  - 1⎠     30   465⋅x  ⋅⎝x
# ───── + ────────────────────────── + ───────────────────────, x   + ──────────
#                  8388608                     33554432                      2
#
#                            2                       3                         4
# 2    ⎞          26 ⎛ 2    ⎞             24 ⎛ 2    ⎞               22 ⎛ 2    ⎞
#   - 1⎠   94395⋅x  ⋅⎝x  - 1⎠    3681405⋅x  ⋅⎝x  - 1⎠    276105375⋅x  ⋅⎝x  - 1⎠
# ────── + ─────────────────── + ───────────────────── + ───────────────────────
#                   8                      16                      128
#
#                           5                           6
#                20 ⎛ 2    ⎞                 18 ⎛ 2    ⎞                  16 ⎛ 2
#    2794186395⋅x  ⋅⎝x  - 1⎠    32598841275⋅x  ⋅⎝x  - 1⎠    113763303225⋅x  ⋅⎝x
#  + ──────────────────────── + ───────────────────────── + ────────────────────
#              256                         1024                        2048
#
#      7                             8                             9
#     ⎞                   14 ⎛ 2    ⎞                   12 ⎛ 2    ⎞
#  - 1⎠    1933976154825⋅x  ⋅⎝x  - 1⎠    2507006126625⋅x  ⋅⎝x  - 1⎠    391092955
# ────── + ─────────────────────────── + ─────────────────────────── + ─────────
#                     32768                         65536
#
#                  10                            11                            1
#       10 ⎛ 2    ⎞                    8 ⎛ 2    ⎞                    6 ⎛ 2    ⎞
# 7535⋅x  ⋅⎝x  - 1⎠     1777695253425⋅x ⋅⎝x  - 1⎠     1777695253425⋅x ⋅⎝x  - 1⎠
# ─────────────────── + ─────────────────────────── + ──────────────────────────
#   262144                         524288                       4194304
#
# 2                           13                          14     ⎛
#                   4 ⎛ 2    ⎞                  2 ⎛ 2    ⎞       ⎜             2
#     220897043325⋅x ⋅⎝x  - 1⎠     22540514625⋅x ⋅⎝x  - 1⎠     x⋅⎝33218887680⋅x
# ─ + ────────────────────────── + ───────────────────────── + ─────────────────
#              8388608                      33554432
#
#                                                              2
# 9                  27 ⎛ 2    ⎞                    25 ⎛ 2    ⎞
#   + 3604249313280⋅x  ⋅⎝x  - 1⎠ + 113233499258880⋅x  ⋅⎝x  - 1⎠  + 1528652239994
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                 3                                 4
#      23 ⎛ 2    ⎞                       21 ⎛ 2    ⎞                       19 ⎛
# 880⋅x  ⋅⎝x  - 1⎠  + 10509484149964800⋅x  ⋅⎝x  - 1⎠  + 40286355908198400⋅x  ⋅⎝x
# ──────────────────────────────────────────────────────────────────────────────
#
#
#       5                                 6                                  7
# 2    ⎞                       17 ⎛ 2    ⎞                        15 ⎛ 2    ⎞
#   - 1⎠  + 90644300793446400⋅x  ⋅⎝x  - 1⎠  + 123017265362534400⋅x  ⋅⎝x  - 1⎠  +
# ──────────────────────────────────────────────────────────────────────────────
#                                                              67108864
#
#                                 8                                 9
#                      13 ⎛ 2    ⎞                       11 ⎛ 2    ⎞
#  101660101237094400⋅x  ⋅⎝x  - 1⎠  + 50830050618547200⋅x  ⋅⎝x  - 1⎠  + 15017969
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                      10                               11
#            9 ⎛ 2    ⎞                       7 ⎛ 2    ⎞                      5
# 500934400⋅x ⋅⎝x  - 1⎠   + 2502994916822400⋅x ⋅⎝x  - 1⎠   + 216605329340400⋅x ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#         12                            13                         14⎞
# ⎛ 2    ⎞                    3 ⎛ 2    ⎞                   ⎛ 2    ⎞  ⎟
# ⎝x  - 1⎠   + 8330974205400⋅x ⋅⎝x  - 1⎠   + 99178264350⋅x⋅⎝x  - 1⎠  ⎠   3005401
# ──────────────────────────────────────────────────────────────────── + ───────
#                                                                              6
#
#            15
#    ⎛ 2    ⎞                                                       2
# 95⋅⎝x  - 1⎠         31          29 ⎛ 2    ⎞            27 ⎛ 2    ⎞    12148636
# ─────────────, 528⋅x   + 61380⋅x  ⋅⎝x  - 1⎠ + 2076690⋅x  ⋅⎝x  - 1⎠  + ────────
# 7108864
#
#               3                          4                           5
#    25 ⎛ 2    ⎞                23 ⎛ 2    ⎞                 21 ⎛ 2    ⎞
# 5⋅x  ⋅⎝x  - 1⎠    1822295475⋅x  ⋅⎝x  - 1⎠    30736050345⋅x  ⋅⎝x  - 1⎠    15368
# ─────────────── + ──────────────────────── + ───────────────────────── + ─────
#    4                         8                           32
#
#                     6                             7
#          19 ⎛ 2    ⎞                   17 ⎛ 2    ⎞                   15 ⎛ 2
# 0251725⋅x  ⋅⎝x  - 1⎠    3754189006425⋅x  ⋅⎝x  - 1⎠    7091245901025⋅x  ⋅⎝x  -
# ───────────────────── + ─────────────────────────── + ────────────────────────
#        64                           1024                          2048
#
#   8                              9                              10
#  ⎞                    13 ⎛ 2    ⎞                    11 ⎛ 2    ⎞
# 1⎠    16546240435725⋅x  ⋅⎝x  - 1⎠    11732788672605⋅x  ⋅⎝x  - 1⎠     195546477
# ─── + ──────────────────────────── + ───────────────────────────── + ─────────
#                   8192                           16384
#
#                  11                            12                            1
#        9 ⎛ 2    ⎞                    7 ⎛ 2    ⎞                    5 ⎛ 2    ⎞
# 87675⋅x ⋅⎝x  - 1⎠     4512611027925⋅x ⋅⎝x  - 1⎠     1041371775675⋅x ⋅⎝x  - 1⎠
# ─────────────────── + ─────────────────────────── + ──────────────────────────
#   131072                         262144                       1048576
#
# 3                          14                        15
#                  3 ⎛ 2    ⎞                  ⎛ 2    ⎞
#     49589132175⋅x ⋅⎝x  - 1⎠     9917826435⋅x⋅⎝x  - 1⎠     32        30 ⎛ 2
# ─ + ───────────────────────── + ───────────────────────, x   + 264⋅x  ⋅⎝x  - 1
#              2097152                    67108864
#
#                                                                        4
#                       2                      3              24 ⎛ 2    ⎞
# ⎞          28 ⎛ 2    ⎞            26 ⎛ 2    ⎞    121486365⋅x  ⋅⎝x  - 1⎠    364
# ⎠ + 15345⋅x  ⋅⎝x  - 1⎠  + 346115⋅x  ⋅⎝x  - 1⎠  + ─────────────────────── + ───
#                                                             32
#
#                    5                           6                           7
#         22 ⎛ 2    ⎞                 20 ⎛ 2    ⎞                 18 ⎛ 2    ⎞
# 459095⋅x  ⋅⎝x  - 1⎠    10245350115⋅x  ⋅⎝x  - 1⎠    21954321675⋅x  ⋅⎝x  - 1⎠
# ──────────────────── + ───────────────────────── + ───────────────────────── +
#         16                        128                         128
#
#                            8                            9
#                 16 ⎛ 2    ⎞                  14 ⎛ 2    ⎞                   12
#  3754189006425⋅x  ⋅⎝x  - 1⎠    787916211225⋅x  ⋅⎝x  - 1⎠    3309248087145⋅x  ⋅
#  ─────────────────────────── + ────────────────────────── + ──────────────────
#             16384                         4096                         32768
#
#         10                             11                            12
# ⎛ 2    ⎞                    10 ⎛ 2    ⎞                    8 ⎛ 2    ⎞
# ⎝x  - 1⎠     1066617152055⋅x  ⋅⎝x  - 1⎠     6518215929225⋅x ⋅⎝x  - 1⎠     3471
# ────────── + ──────────────────────────── + ─────────────────────────── + ────
#                         32768                         1048576
#
#                     13                           14                         15
# ...
#           128                         256                          16384
#
#      8                              9                              10
#     ⎞                    16 ⎛ 2    ⎞                    14 ⎛ 2    ⎞
#  - 1⎠    27577067392875⋅x  ⋅⎝x  - 1⎠    18752405827155⋅x  ⋅⎝x  - 1⎠     162727
# ────── + ──────────────────────────── + ───────────────────────────── + ──────
#                     32768                           32768
#
#                      11                              12
#           12 ⎛ 2    ⎞                     10 ⎛ 2    ⎞                     8 ⎛
# 48858275⋅x  ⋅⎝x  - 1⎠     70515245052525⋅x  ⋅⎝x  - 1⎠     22948748389875⋅x ⋅⎝x
# ─────────────────────── + ───────────────────────────── + ────────────────────
#       65536                          1048576                        2097152
#
#       13                            14                           15
# 2    ⎞                    6 ⎛ 2    ⎞                   4 ⎛ 2    ⎞
#   - 1⎠     4215076234875⋅x ⋅⎝x  - 1⎠     393407115255⋅x ⋅⎝x  - 1⎠     19670355
# ──────── + ─────────────────────────── + ────────────────────────── + ────────
#                      4194304                      8388608
#
#                  16     ⎛
#        2 ⎛ 2    ⎞       ⎜               33                    31 ⎛ 2    ⎞
# 76275⋅x ⋅⎝x  - 1⎠     x⋅⎝2701534429184⋅x   + 378214820085760⋅x  ⋅⎝x  - 1⎠ + 15
# ─────────────────── + ────────────────────────────────────────────────────────
#  2147483648
#
#                             2                                  3
#                  29 ⎛ 2    ⎞                        27 ⎛ 2    ⎞
# 601361328537600⋅x  ⋅⎝x  - 1⎠  + 282124617357721600⋅x  ⋅⎝x  - 1⎠  + 26590245185
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                      4                                    5
#           25 ⎛ 2    ⎞                          23 ⎛ 2    ⎞
# 96526080⋅x  ⋅⎝x  - 1⎠  + 14358732400421240832⋅x  ⋅⎝x  - 1⎠  + 4700775488233144
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                  6                                    7
#       21 ⎛ 2    ⎞                          19 ⎛ 2    ⎞
# 3200⋅x  ⋅⎝x  - 1⎠  + 96533782347644928000⋅x  ⋅⎝x  - 1⎠  + 12670058933128396800
# ──────────────────────────────────────────────────────────────────────────────
#                                                                             42
#
#               8                                     9
#    17 ⎛ 2    ⎞                           15 ⎛ 2    ⎞
# 0⋅x  ⋅⎝x  - 1⎠  + 106991608768639795200⋅x  ⋅⎝x  - 1⎠  + 57872733833946071040⋅x
# ──────────────────────────────────────────────────────────────────────────────
# 94967296
#
#            10                                    11
# 13 ⎛ 2    ⎞                           11 ⎛ 2    ⎞                          9 ⎛
#   ⋅⎝x  - 1⎠   + 19729341079754342400⋅x  ⋅⎝x  - 1⎠   + 4110279391615488000⋅x ⋅⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#        12                                 13                                14
#  2    ⎞                         7 ⎛ 2    ⎞                        5 ⎛ 2    ⎞
# x  - 1⎠   + 496846959426048000⋅x ⋅⎝x  - 1⎠   + 31940161677388800⋅x ⋅⎝x  - 1⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                               15                           16⎞
#                     3 ⎛ 2    ⎞                     ⎛ 2    ⎞  ⎟               ⎛
#  + 931588048923840⋅x ⋅⎝x  - 1⎠   + 8562390155550⋅x⋅⎝x  - 1⎠  ⎠   20419054425⋅⎝
# ────────────────────────────────────────────────────────────── + ─────────────
#                                                                        4294967
#
#        17
#  2    ⎞                      33 ⎛ 2    ⎞                       2
# x  - 1⎠         35   198135⋅x  ⋅⎝x  - 1⎠            31 ⎛ 2    ⎞    337820175⋅x
# ─────────, 666⋅x   + ─────────────────── + 4358970⋅x  ⋅⎝x  - 1⎠  + ───────────
# 296                           2
#
#            3                           4                            5
# 29 ⎛ 2    ⎞                 27 ⎛ 2    ⎞                  25 ⎛ 2    ⎞
#   ⋅⎝x  - 1⎠    13715499105⋅x  ⋅⎝x  - 1⎠    320942679057⋅x  ⋅⎝x  - 1⎠    114622
# ──────────── + ───────────────────────── + ────────────────────────── + ──────
# 4                          16                          64
#
#                     6                              7
#          23 ⎛ 2    ⎞                    21 ⎛ 2    ⎞                     19 ⎛ 2
# 3853775⋅x  ⋅⎝x  - 1⎠    41427805000725⋅x  ⋅⎝x  - 1⎠    483324391675125⋅x  ⋅⎝x
# ───────────────────── + ──────────────────────────── + ───────────────────────
#        64                           1024                            8192
#
#      8                                9                               10
#     ⎞                      17 ⎛ 2    ⎞                     15 ⎛ 2    ⎞
#  - 1⎠    1836632688365475⋅x  ⋅⎝x  - 1⎠    567686467312965⋅x  ⋅⎝x  - 1⎠     180
# ────── + ────────────────────────────── + ────────────────────────────── + ───
#                      32768                            16384
#
#                           11                                12
#                13 ⎛ 2    ⎞                       11 ⎛ 2    ⎞
# 6275123268525⋅x  ⋅⎝x  - 1⎠     1806275123268525⋅x  ⋅⎝x  - 1⎠     1091704744832
# ──────────────────────────── + ─────────────────────────────── + ─────────────
#           131072                            524288                          20
#
#                13                             14
#      9 ⎛ 2    ⎞                     7 ⎛ 2    ⎞                      5 ⎛ 2    ⎞
# 625⋅x ⋅⎝x  - 1⎠     93574692414225⋅x ⋅⎝x  - 1⎠     131004569379915⋅x ⋅⎝x  - 1⎠
# ───────────────── + ──────────────────────────── + ───────────────────────────
# 97152                         2097152                         67108864
#
# 15                             16                          17
#                      3 ⎛ 2    ⎞                    ⎛ 2    ⎞
#      38530755699975⋅x ⋅⎝x  - 1⎠     755505013725⋅x⋅⎝x  - 1⎠     36        34 ⎛
# ── + ──────────────────────────── + ─────────────────────────, x   + 333⋅x  ⋅⎝
#               1073741824                    4294967296
#
#                              2
#                   32 ⎛ 2    ⎞                       3              28 ⎛ 2    ⎞
#  2    ⎞   198135⋅x  ⋅⎝x  - 1⎠            30 ⎛ 2    ⎞    337820175⋅x  ⋅⎝x  - 1⎠
# x  - 1⎠ + ──────────────────── + 726495⋅x  ⋅⎝x  - 1⎠  + ──────────────────────
#                    8                                               32
#
# 4                          5                            6
#                 26 ⎛ 2    ⎞                  24 ⎛ 2    ⎞                  22 ⎛
#     2743099821⋅x  ⋅⎝x  - 1⎠    106980893019⋅x  ⋅⎝x  - 1⎠    163746264825⋅x  ⋅⎝
# ─ + ──────────────────────── + ────────────────────────── + ──────────────────
#                32                         256                          128
#
#        7                              8                              9
#  2    ⎞                    20 ⎛ 2    ⎞                    18 ⎛ 2    ⎞
# x  - 1⎠    41427805000725⋅x  ⋅⎝x  - 1⎠    53702710186125⋅x  ⋅⎝x  - 1⎠    36732
# ──────── + ──────────────────────────── + ──────────────────────────── + ─────
#                       16384                          16384
#
#                        10                              11
#             16 ⎛ 2    ⎞                     14 ⎛ 2    ⎞                      1
# 6537673095⋅x  ⋅⎝x  - 1⎠     51607860664815⋅x  ⋅⎝x  - 1⎠     602091707756175⋅x
# ───────────────────────── + ───────────────────────────── + ──────────────────
#        131072                           32768                          1048576
#
#           12                               13                              14
# 2 ⎛ 2    ⎞                      10 ⎛ 2    ⎞                      8 ⎛ 2    ⎞
#  ⋅⎝x  - 1⎠     138944240251425⋅x  ⋅⎝x  - 1⎠     155957820690375⋅x ⋅⎝x  - 1⎠
# ──────────── + ────────────────────────────── + ─────────────────────────────
#                           1048576                          8388608
#
#                            15                              16
#                  6 ⎛ 2    ⎞                      4 ⎛ 2    ⎞
#   6238312827615⋅x ⋅⎝x  - 1⎠     131004569379915⋅x ⋅⎝x  - 1⎠     2266515041175⋅
# + ─────────────────────────── + ───────────────────────────── + ──────────────
#             4194304                       2147483648                     21474
#
#            17     ⎛
#  2 ⎛ 2    ⎞       ⎜                35                     33 ⎛ 2    ⎞
# x ⋅⎝x  - 1⎠     x⋅⎝12060268167168⋅x   + 1896477169287168⋅x  ⋅⎝x  - 1⎠ + 885022
# ───────────── + ──────────────────────────────────────────────────────────────
# 83648
#
#                         2                                   3
#              31 ⎛ 2    ⎞                         29 ⎛ 2    ⎞
# 67900067840⋅x  ⋅⎝x  - 1⎠  + 1825359275438899200⋅x  ⋅⎝x  - 1⎠  + 19805148138512
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                    4                                     5
#         27 ⎛ 2    ⎞                           25 ⎛ 2    ⎞
# 056320⋅x  ⋅⎝x  - 1⎠  + 124442347470317420544⋅x  ⋅⎝x  - 1⎠  + 47999191167122433
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                  6                                      7
#       23 ⎛ 2    ⎞                            21 ⎛ 2    ⎞
# 6384⋅x  ⋅⎝x  - 1⎠  + 1178551568835595468800⋅x  ⋅⎝x  - 1⎠  + 188240875577907609
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                  8                                      9
#       19 ⎛ 2    ⎞                            17 ⎛ 2    ⎞
# 6000⋅x  ⋅⎝x  - 1⎠  + 1976529193568029900800⋅x  ⋅⎝x  - 1⎠  + 136560198828336611
# ──────────────────────────────────────────────────────────────────────────────
#                     17179869184
#
#                  10                                     11
#       15 ⎛ 2    ⎞                            13 ⎛ 2    ⎞
# 3280⋅x  ⋅⎝x  - 1⎠   + 615555441688335482880⋅x  ⋅⎝x  - 1⎠   + 17756406971778908
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                  12                                   13
#       11 ⎛ 2    ⎞                           9 ⎛ 2    ⎞
# 1600⋅x  ⋅⎝x  - 1⎠   + 31707869592462336000⋅x ⋅⎝x  - 1⎠   + 3321776814448435200
# ──────────────────────────────────────────────────────────────────────────────
#
#
#             14                                 15
#   7 ⎛ 2    ⎞                         5 ⎛ 2    ⎞                       3 ⎛ 2
# ⋅x ⋅⎝x  - 1⎠   + 186849945812724480⋅x ⋅⎝x  - 1⎠   + 4808638311356880⋅x ⋅⎝x  -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#   16                            17⎞                       18
#  ⎞                      ⎛ 2    ⎞  ⎟               ⎛ 2    ⎞
# 1⎠   + 39286260713700⋅x⋅⎝x  - 1⎠  ⎠   83945001525⋅⎝x  - 1⎠         37   246753
# ─────────────────────────────────── + ──────────────────────, 741⋅x   + ──────
#                                            17179869184
#
#                                      2                         3
#   35 ⎛ 2    ⎞             33 ⎛ 2    ⎞               31 ⎛ 2    ⎞
# ⋅x  ⋅⎝x  - 1⎠   48939345⋅x  ⋅⎝x  - 1⎠    538332795⋅x  ⋅⎝x  - 1⎠    50064949935
# ───────────── + ────────────────────── + ─────────────────────── + ───────────
#    2                      8                         4
#
#              4                            5                              6
#   29 ⎛ 2    ⎞                  27 ⎛ 2    ⎞                    25 ⎛ 2    ⎞
# ⋅x  ⋅⎝x  - 1⎠    677545655787⋅x  ⋅⎝x  - 1⎠    11324691675297⋅x  ⋅⎝x  - 1⎠    1
# ────────────── + ────────────────────────── + ──────────────────────────── + ─
#  32                          64                           256
#
#                            7                                8
#                 23 ⎛ 2    ⎞                      21 ⎛ 2    ⎞
# 21335982235325⋅x  ⋅⎝x  - 1⎠    3410889278393025⋅x  ⋅⎝x  - 1⎠    79587416495837
# ──────────────────────────── + ────────────────────────────── + ──────────────
#             1024                           16384                            32
#
#                9                                 10
#     19 ⎛ 2    ⎞                       17 ⎛ 2    ⎞                        15 ⎛
# 25⋅x  ⋅⎝x  - 1⎠    24744451310523945⋅x  ⋅⎝x  - 1⎠     12747141584209305⋅x  ⋅⎝x
# ──────────────── + ──────────────────────────────── + ────────────────────────
# 768                             131072                             131072
#
#       11                                 12                                 13
# 2    ⎞                        13 ⎛ 2    ⎞                        11 ⎛ 2    ⎞
#   - 1⎠     34319227342101975⋅x  ⋅⎝x  - 1⎠     14708240289472275⋅x  ⋅⎝x  - 1⎠
# ──────── + ──────────────────────────────── + ────────────────────────────────
#                        1048576                            2097152
#
#                                14                               15
#                      9 ⎛ 2    ⎞                       7 ⎛ 2    ⎞
#    7704316342104525⋅x ⋅⎝x  - 1⎠     4622589805262715⋅x ⋅⎝x  - 1⎠     571025799
#  + ────────────────────────────── + ────────────────────────────── + ─────────
#               8388608                          67108864
#
#                    16                              17
#          5 ⎛ 2    ⎞                      3 ⎛ 2    ⎞                     ⎛ 2
# 4736295⋅x ⋅⎝x  - 1⎠     186609738390075⋅x ⋅⎝x  - 1⎠     3273855059475⋅x⋅⎝x  -
# ───────────────────── + ───────────────────────────── + ──────────────────────
#  2147483648                       4294967296                   17179869184
#
#   18⎤
#  ⎞  ⎥
# 1⎠  ⎥
# ────⎥
#     ⎦

# %%
xn = np.linspace(-1,1,100)

Roots1 = GetAllRoots(n,xn,Legendre,DLegendre)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\Flutt\OneDrive\Documentos\Universidad\Metodos Computacionales I\Ejercicios libro 2\problema 19.ipynb Cell 9 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/Flutt/OneDrive/Documentos/Universidad/Metodos%20Computacionales%20I/Ejercicios%20libro%202/problema%2019.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> xn = np.linspace(-1,1,100)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Flutt/OneDrive/Documentos/Universidad/Metodos%20Computacionales%20I/Ejercicios%20libro%202/problema%2019.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> Roots1 = GetAllRoots(n,xn,Legendre,DLegendre)
#
# c:\Users\Flutt\OneDrive\Documentos\Universidad\Metodos Computacionales I\Ejercicios libro 2\problema 19.ipynb Cell 9 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/Flutt/OneDrive/Documentos/Universidad/Metodos%20Computacionales%20I/Ejercicios%20libro%202/problema%2019.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> def GetAllRoots(n,xn,Legendre,DLegendre):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Flutt/OneDrive/Documentos/Universidad/Metodos%20Computacionales%20I/Ejercicios%20libro%202/problema%2019.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a>     poly = sym.lambdify([x],Legendre[n],'numpy')
#       <a href='vscode-notebook-cell:/c%3A/Users/Flutt/OneDrive/Documentos/Universidad/Metodos%20Computacionales%20I/Ejercicios%20libro%202/problema%2019.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a>     Dpoly = sym.lambdify([x],DLegendre[n],'numpy')
#       <a href='vscode-notebook-cell:/c%3A/Users/Flutt/OneDrive/Documentos/Universidad/Metodos%20Computacionales%20I/Ejercicios%20libro%202/problema%2019.ipynb#X11sZmlsZQ%3D%3D?line=5'>6</a>     Roots = GetRoots(poly,Dpoly,xn)
#
# IndexError: list index out of range

# %%
Roots1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Flutt\OneDrive\Documentos\Universidad\Metodos Computacionales I\Ejercicios libro 2\problema 19.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Flutt/OneDrive/Documentos/Universidad/Metodos%20Computacionales%20I/Ejercicios%20libro%202/problema%2019.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> Roots1
#
# NameError: name 'Roots1' is not defined

# %%
#cargar los puntos
dT = 10**-4
funcion = funcion(Roots1,dT)
print(funcion)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Flutt\OneDrive\Documentos\Universidad\Metodos Computacionales I\Ejercicios libro 2\problema 19.ipynb Cell 11 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/Flutt/OneDrive/Documentos/Universidad/Metodos%20Computacionales%20I/Ejercicios%20libro%202/problema%2019.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> #cargar los puntos
#       <a href='vscode-notebook-cell:/c%3A/Users/Flutt/OneDrive/Documentos/Universidad/Metodos%20Computacionales%20I/Ejercicios%20libro%202/problema%2019.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> dT = 10**-4
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Flutt/OneDrive/Documentos/Universidad/Metodos%20Computacionales%20I/Ejercicios%20libro%202/problema%2019.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a> funcion = funcion(Roots1,dT)
#       <a href='vscode-notebook-cell:/c%3A/Users/Flutt/OneDrive/Documentos/Universidad/Metodos%20Computacionales%20I/Ejercicios%20libro%202/problema%2019.ipynb#X13sZmlsZQ%3D%3D?line=3'>4</a> print(funcion)
#
# NameError: name 'Roots1' is not defined

# %%
#obetener pesos

def GetWeights(Roots,DLegendre):
    
    Dpoly = sym.lambdify([x],DLegendre[n],'numpy')
    Weights = 2/((1-Roots**2)*Dpoly(Roots)**2)
    
    return Weights

pesos = GetWeights(Roots1,DLegendre)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Flutt\OneDrive\Documentos\Universidad\Metodos Computacionales I\Ejercicios libro 2\problema 19.ipynb Cell 12 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/Flutt/OneDrive/Documentos/Universidad/Metodos%20Computacionales%20I/Ejercicios%20libro%202/problema%2019.ipynb#X14sZmlsZQ%3D%3D?line=5'>6</a>     Weights = 2/((1-Roots**2)*Dpoly(Roots)**2)
#       <a href='vscode-notebook-cell:/c%3A/Users/Flutt/OneDrive/Documentos/Universidad/Metodos%20Computacionales%20I/Ejercicios%20libro%202/problema%2019.ipynb#X14sZmlsZQ%3D%3D?line=7'>8</a>     return Weights
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Flutt/OneDrive/Documentos/Universidad/Metodos%20Computacionales%20I/Ejercicios%20libro%202/problema%2019.ipynb#X14sZmlsZQ%3D%3D?line=9'>10</a> pesos = GetWeights(Roots1,DLegendre)
#
# NameError: name 'Roots1' is not defined

# %%
GetWeights(Roots1,DLegendre)
# Out:
# array([0.00290862, 0.01811556, 0.02178024, 0.02536067, 0.02884299,
#        0.03221373, 0.03545984, 0.04940094, 0.0516557 , 0.05371062,
#        0.05555774, 0.05718993, 0.05860085, 0.05978506, 0.06073797,
#        0.0614559 , 0.06193607, 0.06217662, 0.06217662, 0.06193607,
#        0.0614559 , 0.06073797, 0.05978506, 0.05860085, 0.05718993,
#        0.05555774, 0.05371062, 0.0516557 , 0.04695505, 0.0443275 ,
#        0.04152846, 0.03545984, 0.03221373, 0.02884299, 0.02536067,
#        0.02178024, 0.01811556, 0.00290862])

# %%
#c
T= np.arange(1,20,10E-4)

#calcular integral
def funcion(T,dT):
    return 1/2*(sym.tanh(sym.sqrt(x**2 + dT**2)*(Td/2*T))/sym.sqrt(x**2+dT**2))


NOV = 0.03
dT= 10**-4
I = 0
for i in range(5):
    I += pesos[i]*funcion(Roots1[i],dT)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Flutt\OneDrive\Documentos\Universidad\Metodos Computacionales I\Ejercicios libro 2\problema 19.ipynb Cell 15 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/Flutt/OneDrive/Documentos/Universidad/Metodos%20Computacionales%20I/Ejercicios%20libro%202/problema%2019.ipynb#X20sZmlsZQ%3D%3D?line=10'>11</a> I = 0
#      <a href='vscode-notebook-cell:/c%3A/Users/Flutt/OneDrive/Documentos/Universidad/Metodos%20Computacionales%20I/Ejercicios%20libro%202/problema%2019.ipynb#X20sZmlsZQ%3D%3D?line=11'>12</a> for i in range(5):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Flutt/OneDrive/Documentos/Universidad/Metodos%20Computacionales%20I/Ejercicios%20libro%202/problema%2019.ipynb#X20sZmlsZQ%3D%3D?line=12'>13</a>     I += pesos[i]*funcion(Roots1[i],dT)
#
# NameError: name 'pesos' is not defined

# %%
I
# Out:
#                          ⎛                 _____________⎞
#                          ⎜                ╱  2          ⎟
#   0.0144214967938912⋅tanh⎝132.895196925⋅╲╱  x  + 1.0e-8 ⎠   0.0126803367790396
# - ─────────────────────────────────────────────────────── - ──────────────────
#                          _____________
#                         ╱  2
#                       ╲╱  x  + 1.0e-8
#
#      ⎛                 _____________⎞                         ⎛
#      ⎜                ╱  2          ⎟                         ⎜
# ⋅tanh⎝136.961783505⋅╲╱  x  + 1.0e-8 ⎠   0.010890121592619⋅tanh⎝140.498492835⋅╲
# ───────────────────────────────────── - ──────────────────────────────────────
#      _____________                                            _____________
#     ╱  2                                                     ╱  2
#   ╲╱  x  + 1.0e-8                                          ╲╱  x  + 1.0e-8
#
#   _____________⎞                           ⎛                _____________⎞
#  ╱  2          ⎟                           ⎜               ╱  2          ⎟
# ╱  x  + 1.0e-8 ⎠   0.00905778036550159⋅tanh⎝143.49164328⋅╲╱  x  + 1.0e-8 ⎠   0
# ──────────────── - ─────────────────────────────────────────────────────── - ─
#                                           _____________
#                                          ╱  2
#                                        ╲╱  x  + 1.0e-8
#
#                        ⎛                _____________⎞
#                        ⎜               ╱  2          ⎟
# .00145431130231255⋅tanh⎝149.82996066⋅╲╱  x  + 1.0e-8 ⎠
# ──────────────────────────────────────────────────────
#                       _____________
#                      ╱  2
#                    ╲╱  x  + 1.0e-8

# %%
#Criterio de parada

while np.abs(I-1/NOV) > dT:
    tc = I

# %%
I
# Out:
# 0
